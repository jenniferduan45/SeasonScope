# %% [markdown]
# # BLIP: Bulk Caption Images Automatically
#  - Run each step one after other
#  - Give your Google Drive permission when asked in 1 step
#  - create a folder named "my_images" in your Google Drive
#  - Upload images you want to caption in "my_images" folder
#  - Image captions will we saved in "my_captions" folder in your Google Drive
#  - Caption for each image will be saved as a text file of same name as the    image inside "my_captions" folder

# %% [markdown]
# # 1.Insall Required dependencies

# %%
# !pip3 install transformers==4.30.0 timm==0.4.12 fairscale==0.4.4
# !git clone https://github.com/salesforce/BLIP
# %cd BLIP
# Out:
# Requirement already satisfied: transformers==4.30.0 in /usr/local/lib/python3.10/dist-packages (4.30.0)
# Requirement already satisfied: timm==0.4.12 in /usr/local/lib/python3.10/dist-packages (0.4.12)
# Requirement already satisfied: fairscale==0.4.4 in /usr/local/lib/python3.10/dist-packages (0.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (4.66.1)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.4.12) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.4.12) (0.15.2+cu118)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (16.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (2023.7.22)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.12) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4->timm==0.4.12) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->timm==0.4.12) (1.3.0)
# Cloning into 'BLIP'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 277 (delta 137), reused 136 (delta 135), pack-reused 112
# Receiving objects: 100% (277/277), 7.03 MiB | 12.98 MiB/s, done.
# Resolving deltas: 100% (152/152), done.
# /content/BLIP

# %% [markdown]
# #2. Get images
# Upload your images to "my_images" folder in your Google Drive.

# %%
from PIL import Image
import os
import torch
from torchvision import transforms
from torchvision.transforms.functional import InterpolationMode

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def load_demo_images(image_folder, seasons, image_size, device):
    images = []
    image_names = []
    for season in seasons:
        abs_path = os.path.join(image_folder, season)
        count = 0
        for image_name in os.listdir(abs_path):
            if count == 1500:
                print(f"{season} images loaded")
                break
            img_path = os.path.join(abs_path, image_name)
            raw_image = Image.open(img_path).convert('RGB')

            # w, h = raw_image.size
            # display(raw_image.resize((w//5, h//5)))

            transform = transforms.Compose([
                transforms.Resize((image_size, image_size), interpolation=InterpolationMode.BICUBIC),
                transforms.ToTensor(),
                transforms.Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711))
            ])
            image = transform(raw_image).unsqueeze(0).to(device)
            images.append(image)
            image_names.append(image_name)
            count += 1
    return images, image_names

# %% [markdown]
# # 3. Image Captioning
# - Perform image captioning using finetuned BLIP model.
# - Result will be saved in "my_captions" folder in your Google Drive

# %%
from models.blip import blip_decoder

image_size = 512
images, image_names = load_demo_images('/content/season_images', ['spring', 'summer'], image_size=image_size, device=device)

model_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth'
model = blip_decoder(pretrained=model_url, image_size=image_size, vit='base')
model.eval()
model = model.to(device)

text_folder = '/content'
output_file = 'season_captions.txt'
output_file_path = os.path.join(text_folder, output_file)

with open(output_file_path, "a+") as f:
    with torch.no_grad():
        for i, image in enumerate(images):
            caption = model.generate(image, sample=True, num_beams=3, max_length=40, min_length=5)
            print('caption: '+caption[0])
            image_name = image_names[i]
            f.write(f"{image_name}, {caption[0]}\n")
# Out:
# spring images loaded
# summer images loaded
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: an old bridge over water
# caption: the city from the water
# caption: a white flower on green leaves
# caption: some flowers hanging from the tree
# caption: sakura blossoms growing in my parents garden
# caption: some white flowers
# caption: a tree with pink flowers
# caption: the waves on the ocean
# caption: the flowers and shrubs in bloom
# caption: my wife, under the pink blossoms
# caption: pink flowers on a field
# caption: a white flower in a garden
# caption: the branches and flowers on the trees
# caption: istanbul from the water
# caption: a cup and two flowers
# caption: a tree with a lot of purple flowers
# caption: a flower with a bee on it
# caption: some white flowers on a tree
# caption: little girl with her eyes closed in the middle of the field of flowers
# caption: blue flowers growing in the grass
# caption: a white flower with a red center and a purple background
# caption: the trees and ferns in the forest
# caption: an empty coffee cup with daies in it the mug is beside to show you the quote still life
# caption: flowers that are in black and white
# caption: some flowers against a yellow background
# caption: the yellowstone grand prism site from the top of mount yellowstone
# caption: an old building with flowers and windows
# caption: an orange and brown bird on a branch
# caption: some purple crocy flowers in the garden
# caption: a flower sitting on some grass
# caption: an orange substance on the surface of a large lake
# caption: flowers on a tree
# caption: a flower on the branches
# caption: flowers with the sky and clouds behind them
# caption: a dandela plant in the grass
# caption: a tree with white flowers
# caption: wildflowers in bloom
# caption: two people walking down an old narrow street in barcelona
# caption: flowers in a vase
# caption: some flowers with drops of dew
# caption: some yellow flowers
# caption: yellow crocus tulipinus'a great spring bulb '
# caption: a road going through some trees
# caption: the blossoms in bloom
# caption: a rose
# caption: the reflection of a person in a camera
# caption: a grass field stock photo
# caption: a small kitten
# caption: a large buddha statue with pink cherry trees behind it
# caption: a colorful flower that looks like a tulipixer
# caption: red flowers in the sun
# caption: a plant with leaf veins
# caption: a lady with her baby
# caption: purple flowers on the branches of a tree
# caption: grass with green leaves growing on the ground
# caption: leaves and sky
# caption: a crowded street
# caption: some pink flowers
# caption: a kitten laying on the ground eating
# caption: the blue and white lines of a diamond
# caption: spring flowers and blue sky
# caption: a sheep
# caption: flowers that are laying on the floor with gloves and an orange paper bag
# caption: flowers
# caption: trees that are blooming in spring
# caption: some very small trees in the water
# caption: some pink flowers with blurs
# caption: the wooden ceiling
# caption: the veins of a leaf with drops on it
# caption: some white flowers in the dark
# caption: a basket of flowers with paste background
# caption: pink flowers on a tree
# caption: a dan flower
# caption: a bird that is nesting in a nest
# caption: orange and yellow tulipow
# caption: the top of an old building
# caption: flowers on a tree
# caption: a bunch of pink cherry blossoms
# caption: flowers that are in my vase
# caption: tall grass in a field
# caption: wild flowers and grass
# caption: people jumping and playing in the water
# caption: the flowers and branches in bloom
# caption: a smiling woman surrounded by the red flower
# caption: some leaves on a ground
# caption: flowers with leaves and stems
# caption: dandela flowers with sun in the background
# caption: a bird sitting on a branch
# caption: trees in the sky
# caption: a classic car parked on the cobb road
# caption: a creek, and a house
# caption: a tractor pling the land
# caption: some flowers in blooming
# caption: the back of a woman wearing a white summer sun hat and pale blue dress and matching with a light tan colored, pink background
# caption: a bee flying to some flowers
# caption: the tree in the courtyard
# caption: the washington capitol and the washington monument in the distance
# caption: a dog outside with flowers
# caption: some very bright flowers
# caption: some flowers near the ocean
# caption: the ground gec with wildflowers
# caption: a blossoming tree in full bloom
# caption: the waterfalls in the river
# caption: a grass with green leaves
# caption: the beautiful cherry blossoms in blossom
# caption: tulipliplip on a meadow in the countryside in belgium
# caption: blossom buds against the sky
# caption: yellow flowers against a blue sky
# caption: a bush of pink flowers
# caption: a country road
# caption: some flowers in the rain
# caption: a tree with pink flowers
# caption: some yellow and red flowers
# caption: cherry blossom
# caption: the mountains that were on a trail
# caption: a woman holding a glass of a wine
# caption: wild flowers taken in an early morning and a single flower that is still in focus
# caption: blooming tree branches
# caption: some green trees on a river
# caption: trees in spring
# caption: a cat on the back
# caption: pink flowers and a blue sky
# caption: flowers on the side of a black background
# caption: some red flowers and green leaves
# caption: some green and brown grass
# caption: some purple flowers and green grass
# caption: a bride kissing in the sun
# caption: soil
# caption: a couple in the forest
# caption: the beautiful flowers at the 2018 chicago flower show
# caption: field of red and yellow wild flowers with lots of green in the background
# caption: colorful spring flowers
# caption: twigs with the sky in the background
# caption: some purple flowers and leaves
# caption: ladybird on a green leaf
# caption: a woman in white coat leaning between the cherry trees
# caption: flowers on a tree
# caption: a field of pink tulipopis turtum
# caption: some small white flowers with green leaves
# caption: someone giving me another man holding it
# caption: flowers on the tree in front of a blue sky
# caption: yellow flowers with black background
# caption: some different types of flowers
# caption: someone riding a bike
# caption: some dairy cows on the edge of lochin island - loch stock videos & royalty footage
# caption: a field with sunflowers on the side
# caption: pink peonia flowers growing on rocks
# caption: dark water
# caption: the white arch on top of a beach
# caption: some flowers that are in a pot
# caption: a truck parked in front of a house and a dirt path that leads up to the house
# caption: a river in the middle - east - south section
# caption: spring croc in the woods
# caption: pink cherry blossoms on a tree
# caption: a cherry blossom against the blue sky
# caption: an orange and white flower
# caption: some purple crocins
# caption: people walking down a sidewalk in alsace
# caption: the sky and some tree blossoms
# caption: daxo tuscata daxoo
# caption: an oak tree with nuts
# caption: some white flowers in a black background
# caption: a white flower on a tree
# caption: some pink flowers in the sun
# caption: a pink bird sitting on a branch
# caption: a young girl wearing white blouse with purple flowers
# caption: purple and white flowers in front of blue sky
# caption: yellow flowers with green stems
# caption: a vase filled with pink flowers
# caption: some white flowers and yellow ones
# caption: someone holding a cup in his hand
# caption: a man with beard wearing a hat
# caption: pink flowers against a blue sky
# caption: a road in the field with flowers
# caption: an area in the garden that has a variety of trees
# caption: a bee on a flower
# caption: the leaves and branches of a plant
# caption: an old cemetery that appears in the old city of new haven
# caption: some white flowers on a tree
# caption: wind turbines standing in a field
# caption: a vase and flowers in it
# caption: a flower that has been found by the neighbor
# caption: flowers and leaves on the trees
# caption: a group of people going up a hill
# caption: crocus growing in the garden
# caption: a small gray and white puppy dog
# caption: some green leaves with water droplets
# caption: red leaves on the branch
# caption: snowdrops and other flowers in the ground
# caption: purple flowers on trees
# caption: a person standing in front of purple blossom trees
# caption: some purple and white crocus flowers in the grass
# caption: red and white tulipows, one of the dutch tusks
# caption: blue hydra flowers
# caption: some very colorful tulipoo tuliposse tulipooepoo
# caption: a white paper
# caption: some pink flowers with a blue sky in the background
# caption: leaves and buds on a branch
# caption: a green, leaf filled area in the middle of a grassy and forested area
# caption: the auckland tower surrounded by pink blossoms
# caption: two flowers in a pot
# caption: a big cloud in the sky
# caption: a girl with red leaves in her hair looking up at the trees
# caption: an empty snow covered path
# caption: purple flowers growing in the garden
# caption: white flowers on the branch
# caption: some flowers that are in the background
# caption: an outside
# caption: some flowers in the grass
# caption: white tuliplip flowers
# caption: a white flower on a stalk
# caption: some white and green leaves
# caption: flowers on a branch in front of a sky
# caption: some houses in the water and mountains
# caption: the mountains and a lake with boats docked at the end
# caption: a flower field with many flowers
# caption: some pink flowers in a vase
# caption: a basket full of easter eggs
# caption: colorful easter eggs and chocolate eggs
# caption: leaves that are green
# caption: two palm trees that are silhouetted against the dark sky
# caption: an graveyard on a fall evening
# caption: some very pretty blue and pink crocines
# caption: the path to a woodside
# caption: the back end of a jet
# caption: some buildings in the sky
# caption: yellow flowers and some green leaves
# caption: some kind of flowers
# caption: a flower field in the middle of a field with blue skies
# caption: flowers and plants on the ground
# caption: the farmers'market
# caption: some flowers that are red
# caption: trees covered in white flowers
# caption: an orange flower that is in bloom
# caption: a tree that is bright green in color
# caption: a rural setting in the hills
# caption: a water fountain surrounded by flowers
# caption: trees that are blooming in spring, and the color changes them
# caption: street art in a small town
# caption: the stripe dress in light blue
# caption: a field that looks like it is taken at sunset, with the sun breaking in from behind
# caption: the mountains and lake
# caption: a building on a street
# caption: flowers
# caption: an orange off the shoulder cropped sweater and ripped jeans
# caption: the roses that were planted around the tomb
# caption: some dessert on a plate
# caption: a rose with some leaves
# caption: a cherry tree with white flowers
# caption: white flowers with some green leaves
# caption: panacena's wild flowers in the garden
# caption: an old train ride in red, orange and blue
# caption: pink flowers and blue sky
# caption: the mediterranean islands with the waves crashing against the rocks
# caption: pink flower with droplets
# caption: flowers that are in a vase
# caption: some flowers on a branch
# caption: a rooster with colorful feathers, surrounded by some different kinds of paint and mixed media
# caption: some flowers that are outside
# caption: a drone sitting in the grass
# caption: a woman sitting on a bench overlooking a lake
# caption: the road in the field
# caption: a bird on the ground
# caption: flowers hanging in the branches
# caption: a bird that is sitting on some rocks
# caption: three robin eggs in the nest
# caption: flowers on a tree
# caption: a beautiful bird that is perched
# caption: two birds in water
# caption: flowers and petals on a tree
# caption: purple flowers on the ground
# caption: pink flowers on the branches
# caption: many tulipas
# caption: some very small rocks in the woods
# caption: a branch with white flowers in the sky
# caption: an apple tree with flowers
# caption: blossom with blue sky in the background
# caption: a flower on a plant
# caption: a single white flower
# caption: someone reaching for the flowers
# caption: some pretty flowers in the trees
# caption: a pink tree with many flowers
# caption: a bridge over a waterfall in the forest
# caption: some pink flowers growing in the garden
# caption: pink blossoms in the sunlight
# caption: an insect on the leaf
# caption: sunbeams in the woods
# caption: the sky with some flowers on it
# caption: someone's cat walking through a narrow alley
# caption: flowers
# caption: some pink cherry blossoms against a blue sky
# caption: the path into a home
# caption: a woman holding flowers at an indoor farmer's market
# caption: green mossy with small leaves
# caption: two little birds walking away
# caption: a field full of flowers
# caption: daffus field
# caption: a flower in the sky
# caption: a yellow - bell bird perched on a tree branch
# caption: flowers growing on a tree
# caption: some white flowers
# caption: a bee on a flower
# caption: the blossoms on trees at south park in brooklyn, ny
# caption: a lightning in the distance, with the sky shining above
# caption: a field with some flowers
# caption: some flowers in the sky
# caption: flowers growing in the ground
# caption: a woman on her cell phone
# caption: some flowers with blurry
# caption: some pretty white flowers
# caption: the mountains and green trees with the sun rising above
# caption: a field full of pink flowers
# caption: some flowers with blur and light colors
# caption: some trees in the woods
# caption: trees that are blooming in spring
# caption: a green and white house
# caption: a bike parked on the side of a road
# caption: a flower in the sky
# caption: the forest with trees on each side
# caption: a young woman in a field
# caption: a border col col col col col in a field of croc
# caption: two flowers in the center of the photo
# caption: some drinking glasses filled with water
# caption: an arrangement of tulipps in a glass vase on a table
# caption: fall trees
# caption: some very interesting looking flowers
# caption: some pink flowers
# caption: a leaf that is growing in the forest
# caption: a white flower with purple center and petals
# caption: pink flowers on a branch
# caption: some pretty white flowers
# caption: a lion resting with his head on the ground
# caption: a bottle with coloured liquid
# caption: tulipliplip in front of trees and buildings in the morning sun
# caption: white birch trees in the autumn season
# caption: some white dai dai dai dai dai dai dai dai dai dai dai dai dai dai dai dai
# caption: white flowers against a blue sky background
# caption: a small spider, with two legs, on a rock
# caption: the steerings in the seat of a sports car on a beach
# caption: a purple flower
# caption: a flower in the grass
# caption: pink flowers
# caption: some pink flowers on a tree
# caption: some flowers on a tree
# caption: pink flowers in the sun
# caption: snow capped mountains in the alps
# caption: a garden with cherry trees
# caption: some pink flowers on the branch
# caption: tulipps with one in yellow and one in pink
# caption: a person in front of a tall church
# caption: pink flowers on the trees
# caption: a mother and her baby with the text 5 tips on how to choose the best nanny for
# caption: a swan swimming in the water
# caption: a brown and white dog on grass
# caption: a girl in a field doing a back flip
# caption: a white and black vase with purple flowers
# caption: some pink flowers on a tree
# caption: a sign saying
# caption: a white flower with yellow centers
# caption: the smoke haze from the bush fire on the outskirts
# caption: pink magnolia blossom in front of a gray wall
# caption: the grass is frozen in some water
# caption: a white cherry blossom
# caption: a man wearing floral shirt standing in front of tree
# caption: pink flowers with a blue sky in the background
# caption: a chocolate covered dessert on a table
# caption: a plant that is growing inside a patch of green
# caption: flowers against the sky
# caption: flowers
# caption: some white flowers with red and green leaves
# caption: some cher on a plate
# caption: flowers that are blooming in the garden
# caption: a bee on a purple flower
# caption: a little girl in her own playing with bubbles and floating balloons
# caption: a rose from our garden
# caption: a bike parked by the beach
# caption: a hand reaching out of a plant
# caption: asparad
# caption: pink flowers in the sky
# caption: a honeybee hovering on purple flowers
# caption: mountains covered in clouds on a cloudy day
# caption: purple flowers in the grass
# caption: some very apple trees
# caption: some flowers and some leaves
# caption: pink flowers hanging from a branch
# caption: someone playing a flute
# caption: a frog sitting on top of a plant
# caption: white and pink blossoms with blue sky in the background
# caption: a building with a stone facade
# caption: the pink flowers that are blooming in a flower pot
# caption: some pretty purple crocus blooming in the sunlight in a very light with a little blur to it
# caption: pink flowers
# caption: some very small flowers with many smaller ones
# caption: some pink flowers with dark green leaves
# caption: some flowers that are growing in the ground
# caption: the sky and clouds
# caption: white flowers growing on top of a tree
# caption: purple crocus on the ground
# caption: a flower growing in the grass
# caption: yellow dasies in the rain
# caption: leaves
# caption: a person riding a bike down the street
# caption: clouds on the sky
# caption: flowers with a sky background
# caption: an aerial view of a lake in the woods
# caption: a flower in the center
# caption: two young women that are smiling at the camera
# caption: person holding match on park bench
# caption: flowers that are in a flower pot
# caption: some white flowers on a tree
# caption: flowers
# caption: a very old outbuildinged cabin sitting in the woods
# caption: flowers and branches with blurred background
# caption: some snow on a mountain
# caption: flowers taken on a small device
# caption: someone throwing a disc
# caption: some eggs in a bowl
# caption: a pink flower on a branch
# caption: a man's feet in the middle of fall leaves
# caption: two pastries with chocolate and cinnamon
# caption: cherry blossoms with the words
# caption: a field with many blue flowers
# caption: purple flowers under a dark sky
# caption: some white flowers in the dark
# caption: an empty town in the day
# caption: a meadow with many different flowers
# caption: a butterfly on a flower
# caption: leaves on the ground
# caption: a horse with a blanket around its neck
# caption: buildings and the city skyline
# caption: figs and two slices
# caption: some food on a wooden table
# caption: pink flowers in a vase
# caption: a yellow porsche car and an orange porsche
# caption: some flowers that are in the garden
# caption: purple flowers in the garden
# caption: an eastern gray squirrel eating
# caption: the rosebud flower that looks like a leaf
# caption: pink flowers
# caption: some flowers in the woods
# caption: a mountain road with mountains in the background
# caption: a white daisy with yellow centres
# caption: a bee poll worker with wings, sitting on the yellow flower
# caption: a bunny in centrale
# caption: a cheese cake on top of a wooden stump
# caption: pink flowers growing in the bush
# caption: tulipassa tulipas
# caption: a goat staring into the camera
# caption: lady wearing fur coat, looking down
# caption: a tree and a path in a forest
# caption: the windmills in the water
# caption: flowers in bloom
# caption: the blossom of a tree
# caption: some white flowers with green leaves
# caption: the same shrub, in late autumn, with many orange and yellow leaves
# caption: some pink flowers
# caption: the beautiful blooms of a peach tree
# caption: a dog looking for food in the grass with its tongue hanging out in front of it
# caption: white flowers
# caption: trees from above
# caption: some white flowers and some red
# caption: purple flowers
# caption: green grass with the sun in the background
# caption: a beautiful bluebell flower
# caption: flowers on the branches
# caption: the road in a foggy forest
# caption: a house, tree and lawn in a cemetery
# caption: an apple tree with white flowers
# caption: some white flowers in the grass
# caption: orange and white striped amar lillies
# caption: the sky with the white flower
# caption: flowers and an iphone
# caption: pink blossoms against a light blue sky
# caption: a path in the woods with some leaves on it
# caption: a tree with yellow blossoms
# caption: green mountain land with a fog
# caption: some flowers in the background
# caption: a red light house
# caption: some pretty pink flowers
# caption: young couple hugging in tuliplipp
# caption: four red flowers and a yellow flower
# caption: some grass
# caption: a small island surrounded by trees
# caption: the hole in the bark of an oak tree
# caption: cherry blossom
# caption: some pretty blossoms
# caption: a mountain with many animals in it
# caption: pink flowers with the stems open
# caption: flowers and notebook with an apple and an iphone
# caption: some houses outside the sky
# caption: a birdhouse and some lavender spii
# caption: flowers and leaves in the sun
# caption: das and some leaves on a wooden table
# caption: some very beautiful flowers
# caption: a red flower in front of a building
# caption: a purple flower on a black background
# caption: blossoms in the springtime
# caption: a woman sitting on top of a wall in an urban area
# caption: a butterfly resting on some flowers
# caption: a smiling woman with yellow tulipps
# caption: a bike with lots of things in the basket
# caption: a young girl looking into a fridge door while eating her food in the fridge
# caption: green fields with the sun reflecting in the center
# caption: cherry trees with some water and a building
# caption: purple flowers on the ground
# caption: the sky and white blossom on the tree
# caption: lila flowers with blurred white background
# caption: a small pink flower on a tree branch
# caption: tuliploa, netherlands
# caption: a bee on a branch with white flowers
# caption: grass with the green background
# caption: a young girl holding a sunflower
# caption: a cat sitting on a white table
# caption: some pretty looking flowers
# caption: a beautiful mountain valley with trees and a river
# caption: buildings along the water in this picture
# caption: flowers in front of mountains
# caption: colorful flowers taken from above
# caption: pink tulipps against a red brick wall
# caption: some flowers that are beautiful
# caption: some plants and trees
# caption: a bee sitting in front of flowers
# caption: a pine tree
# caption: daxous in full bloom, showing the beautiful golden flower colours with the background and colors of the spring landscape
# caption: butterfly on flowers
# caption: purple flower
# caption: leaves with the text, the night comes again
# caption: two tulipps, one for each, and the one for a book
# caption: red tulipowes with green stems
# caption: yellow tulipi flowers
# caption: a pink flower in the grass
# caption: a person standing alone, as the sun sets in on a cloudy sky
# caption: flowers against a blue sky
# caption: one of the first of tiny suercris crocoliata blooms
# caption: the finished panna cota with ras jam syrup on a plate
# caption: a field with rows of tulipys
# caption: a pink flower on a white wall
# caption: leaves and rocks
# caption: a river with people and a bridge
# caption: a bunch of yellow flowers
# caption: a small white flower surrounded by green leaves
# caption: a girl with her hands on a bouquet
# caption: yellow sunflowers in a large field
# caption: a dog in a backyard garden
# caption: a tree with pink flowers
# caption: a girl looking surprised in a tree full of pink blossoms
# caption: a young woman standing in the shadows
# caption: a newborn sleeping in a bucket
# caption: the table
# caption: leaves
# caption: orange tulipps against a blue sky
# caption: green sprag on top of soil
# caption: flowers on a tree
# caption: a kitten laying on the ground with flowers and petals
# caption: some flowers in a vase
# caption: white flowers with some yellow and green flowers
# caption: some flowers on some branches
# caption: some yellow flowers in a field
# caption: a beautiful pink blossom tree with lots of blossoms
# caption: some flowers on the branches
# caption: some white and yellow daisiess
# caption: yellow flowers with purple leaves and pink flowers in the background
# caption: the bridge
# caption: a woman doing yoga poses
# caption: a woman walking along the water
# caption: crocy tulipites
# caption: an old church with a cross
# caption: blossom flowers on a branch
# caption: flowers with water on them
# caption: white flowers on a tree branch
# caption: several types of shirts
# caption: white blossoms with green leaves
# caption: some white flowers on a plant
# caption: woman outside, wearing black shirt, belt and short skirt
# caption: a field of sunflowers, the netherlands
# caption: a flower with red and yellow petals
# caption: crocus flowers
# caption: a ginger colored cat
# caption: pink flowers on a gray background
# caption: some white flowers on a tree
# caption: a sandwich and a fork
# caption: a monarch cater on a plant
# caption: a tree in fall with lots green leaves
# caption: a bunch of flowers in a vase
# caption: a lush field with tall grass
# caption: a flower that is close to focus
# caption: some leaves that are yellow
# caption: purple flowers and blue sky in the background
# caption: a plant with white flowers
# caption: flowers in the middle of pink blossoms
# caption: purple wismunda flowers growing on a vine
# caption: purple flowers
# caption: the washington capitol fountain in april - with springtime flowers and a small bird
# caption: pink flowers with a cloudy sky in the background
# caption: plants growing next to the road, shot with a canon 600d
# caption: a tree with lots flowers
# caption: a snowboarder in the snow
# caption: some flowers in the woods
# caption: a woman sitting next to flowers
# caption: an area with trees and plants
# caption: the lighthouse at the top of a hill
# caption: a field of lavender
# caption: two tulipis on a white sheet
# caption: rocks stacked on top of each other rocks on the river bank
# caption: a field of purple and white orchids
# caption: a hand reaching to a blooming pink flower in the park
# caption: the sun shining through a forest
# caption: a tiny green plant in the ground
# caption: a small white flower on a tree
# caption: a lamb
# caption: a city street
# caption: swarm of bees going into an hive box
# caption: the sky with white clouds
# caption: two swans in water
# caption: a bug crawling on purple flower
# caption: mushrooms, an egg, and other vegetables
# caption: the mountain range and its valley
# caption: a wall covered with moss
# caption: some grass in a small pond
# caption: a waterfall in the mountains
# caption: easter decorations
# caption: a red and blue building
# caption: cherry flowers with a sky background
# caption: trees and grass at sunset
# caption: a model who is walking and carrying the bag she is wearing, wearing the white tank and shorts
# caption: flowers in the window with blurry background
# caption: a lake in the mountains
# caption: white blossoms and leaves
# caption: the rainforest canopy
# caption: a red flower near a grey wall
# caption: snow in a tree
# caption: many white, yellow and purple flowers
# caption: a flowering tree in a snowy day
# caption: a sculpture in the middle of a city
# caption: a woman walking on railroad tracks
# caption: the mountains reflected in water
# caption: pink flowers with a blue sky
# caption: a flower with water droplets on it
# caption: a woman sitting on a rock
# caption: a tree with drops of water on it
# caption: a small dog standing and yacing
# caption: pink blossoms, against the blue sky
# caption: a tree in the spring
# caption: an empty palm tree against the blue sky
# caption: purple crocum
# caption: some white flowers that are sitting on green leaves
# caption: a pink flower with leaves in the background
# caption: an oreocaa plant with flowers
# caption: blossom blossoms in spring
# caption: da's cottage surrounded by da's da da
# caption: a single purple flower
# caption: an thistle plant in the sunset by brian murphy
# caption: a pink flower on the ground
# caption: corn and the sky at stowe farms, with trees and blue skies in the background
# caption: yellow iris flower
# caption: a forest that has lots trees in it
# caption: a girl standing in front of trees during the cherry blossom festival
# caption: a bunch of flowers
# caption: an orange bicycle that is sitting on the floor
# caption: some yellow flowers
# caption: two white flowers with one flower bud in the middle, among among
# caption: a construction site with dirt
# caption: a trail through the woods
# caption: yellow flowers growing out of some grass
# caption: a building in japan taken with a hoy
# caption: a white tree with lots flowers
# caption: a branch with some flowers
# caption: a person sitting on some boats
# caption: a garden statue
# caption: white flowers with pink centers
# caption: a woman in white on her back with no body standing against the side of an old wall
# caption: many purple flowers in the ground
# caption: flowers on a pink background
# caption: some beautiful pink flowers on the branch
# caption: a flower with water droplets
# caption: a bird on a branch
# caption: cherry blossoms
# caption: beautiful redhead - haired woman in the spring season
# caption: deer that is standing on the street
# caption: some pink flowers in front of some green leaves
# caption: some blue flowers
# caption: cherry blossoms on a tree
# caption: a flower that is in the grass
# caption: pink flowers on a tree
# caption: the top of some flowers and branches
# caption: a road that is in the mountains
# caption: a stream running through the forest
# caption: flowers growing in the grass
# caption: white flowers with some green leaves
# caption: the washington monument in blooming cherry trees on the tidal river
# caption: people walking under the bridge
# caption: a beautiful pink tree
# caption: a tree with pink flowers
# caption: a bird and its nest
# caption: the berlin skyline
# caption: downtown denver, colorado
# caption: some trees against a sunset sky
# caption: a flowering tree
# caption: a person riding a mountain bike through the woods
# caption: a butterfly on some yellow and white flowers
# caption: the beach in the middle of summer
# caption: a single pink flower
# caption: a small mouse on a red background
# caption: an old orange car that is sitting next to a tree
# caption: a flower taken by a canon with no edits
# caption: the sky at dusk
# caption: some flowers in my backyard
# caption: the yellow flowers of acacia bons - flobanous jaci
# caption: a bush of purple flowers
# caption: an adorable french bulldog with a purple scarf
# caption: someone holding up a shell
# caption: a man standing among sunflowers
# caption: a vase of yellow flowers
# caption: an cherry blossom on the tree
# caption: purple flowering tree blossoms
# caption: flowers that are growing on a tree
# caption: a man with brown hair and a hat looking at the camera surrounded by leaves
# caption: the waterfall at iceland's famous gessonir waterfalls, photo by peter klo
# caption: snowdrop flowers on the ground
# caption: some very little flying insects
# caption: a seed
# caption: a flower pot on the ledge in the window of a pink house
# caption: the beach from above
# caption: the marina in vancouver at sunset
# caption: a yellow flower in the middle of summer
# caption: a beautiful pink flower in the sun
# caption: a man and cow on the grass
# caption: cherry trees with pink flowers on them
# caption: some baby lambs on the ground
# caption: snow and a house
# caption: some pink flowers against a blue sky
# caption: pink and white flowers
# caption: a woman drinking coffee
# caption: a leaf showing the vein on it's surface
# caption: flowers on a tree with a blue sky in the background
# caption: the disneyland park carousel and tree blossoms
# caption: a tree with pink flowers
# caption: some flowers in the grass
# caption: trees from above
# caption: an blooming tree against a blue sky
# caption: rocks on a hill
# caption: a building with windows on it
# caption: leaves and flowers
# caption: a bird sitting on a flower tree branch
# caption: some pink flowers in the dark
# caption: plants in baskets and a straw hat on the windowsill
# caption: a purple flower in the night
# caption: spring
# caption: some flowers near trees
# caption: the hills in the middle of a green valley surrounded by grass and a mountain range in the image is a hd format
# caption: snow covers the ground and crocola spikii with its beautiful, yellow petals
# caption: some white flowers and some green leaves
# caption: red and yellow petunias hanging on a fence
# caption: a lady bug on a flower
# caption: flowers and leaves
# caption: people sitting in a table at a bar
# caption: crocus
# caption: eggs
# caption: the california desert with yellow flowers and a dark background
# caption: a blue vase with some yellow flowers
# caption: some green foliage in a garden
# caption: some very violet crocys flowers
# caption: some pink flowers on a tree branch
# caption: sakura flowers and sky
# caption: the branches of apple trees
# caption: an entrance sign for a small road
# caption: an empty farm with grass and trees
# caption: a bird on a tree with pink flowers
# caption: a pink and white rose
# caption: spring blossoms on the branches against a blue sky background
# caption: a forest with a clear sky behind
# caption: tulipin florisa tulipii flowers in tulipinio flower market
# caption: pink flowers in the tree
# caption: flowers and greene that is a flower arrangement
# caption: a mountain with trees in front
# caption: the sun setting on the surface of a river surrounded by trees
# caption: pink blossoms against blue sky
# caption: a bed, flowers and a tv remote
# caption: a backpacker resting on rocks near the river bank
# caption: some flowers in the sky
# caption: purple flowers in a grassy field
# caption: a field of yellow daffs
# caption: sakura blossoms
# caption: a young woman in the background of spring flowers
# caption: a building with a clock on it
# caption: the sun on some green leaves
# caption: some very flowers that i just found in my park
# caption: a street in the city
# caption: trees in the woods during autumn
# caption: some flowers that are on the tree
# caption: some flowers that are in the same picture
# caption: some very old stone buildings
# caption: grass with a little toy on it
# caption: a woman laying in the grass
# caption: three leaves floating over each other leaf
# caption: the jefferson memorial
# caption: a butterfly on a purple flower
# caption: a dirt road surrounded by many trees
# caption: a pink flowered tree with white blossoms in front of a blue sky
# caption: a gazel running through a field
# caption: a waterfall and some trees
# caption: an apple blossom tree
# caption: some trees, water and green grass
# caption: a car parked in front of a building
# caption: snowdrops with some green leaves in the background
# caption: a street with trees and a bus
# caption: an empty road going through the middle of pine forest
# caption: a bird sitting on a branch
# caption: a bunch of flowers growing in bloom
# caption: some buildings and buildings in the water
# caption: moss growing on a tree trunk with fall leaves
# caption: a plant with leaves on it
# caption: a girl with blonde hair holding flowers in front of her
# caption: a purple flower on a tree
# caption: a rural road through some flowers
# caption: some blue flowers that are scattered in the grass
# caption: purple flower taken from the back
# caption: a bird in a forest
# caption: a monarch butterfly flying into a flower
# caption: snow with purple crocus flowers growing out of it
# caption: grass and water droplets
# caption: a person on top of the hill
# caption: rice terraces in yuancai, yuanco
# caption: the hoodie jacket in black
# caption: two bright yellow flowers in a field
# caption: some pretty, fake roses with some leaves hanging on
# caption: red flowers
# caption: purple flowers with blur lines in the background
# caption: corn fields during a weather test
# caption: a blooming pink flower
# caption: leaves and branches
# caption: some very looking flowers
# caption: a bush of pink roses
# caption: a pool that is empty
# caption: white flowers on a tree
# caption: forget forgeters, the most common pri will ever
# caption: red tulipes in blooming a park
# caption: woman placing bricks on wall
# caption: flowers with some bright pink petals
# caption: an empty alley with two windows
# caption: a grassy field with trees
# caption: a pine plant with the leaves falling off of it
# caption: a beautiful blonde woman posing under cherry blossoms
# caption: hanging plants
# caption: an area that is covered in white flowers
# caption: a basketball court with benches in the fore
# caption: a close - up of purple flowers with large green leaves
# caption: red and white tulipos in a field of blue wildflowers and a red tuliposis
# caption: some plants that are very big
# caption: a bike parked by the water in the park
# caption: a white flower with yellow centers
# caption: the red barn in the middle of nowhere
# caption: a small flower in the garden
# caption: pink flowers with a brown background
# caption: a yellow flower
# caption: a city that is in disrepair
# caption: sakura flowers in the sun
# caption: some yellow and blue flowers
# caption: some white and pink flowers
# caption: some purple flowers
# caption: a bee flying near pink blossomy buds
# caption: a cherry tree in full bloom
# caption: pink flowers on the side of a building
# caption: a pair of shoes sitting on the ground
# caption: an old man sitting on a bench
# caption: some purple flowers in a tree
# caption: a flower field with the sun beaming through the flowers
# caption: trees by the water
# caption: flowers that are very pretty
# caption: some pretty suphiloria plants
# caption: leaves covered with water drops
# caption: some purple flowers in front of a white wall
# caption: some flowers on the branches
# caption: the striped twil blouse in forest green
# caption: two pink roses
# caption: the ocean and a sail boat
# caption: some ivys growing on the wall
# caption: a white flower growing in the middle of a green forest
# caption: some small flowers growing from the ground
# caption: a spider sitting in the grass
# caption: two chairs and an orange chair
# caption: a tree with many pink flowers
# caption: flowers in front of the church
# caption: the canals and old houses in cols
# caption: a tree with leaves in the fore
# caption: a single rose
# caption: flowers floating in water
# caption: some flowers and dirt
# caption: some flowers
# caption: tall grass
# caption: pink tulip
# caption: a drop falls into the red background
# caption: white flowers against a blue sky
# caption: the beautiful cherry blossoms
# caption: flowers on a pot in front of a window
# caption: cherry trees in bloom and an arch behind
# caption: two children running along a dirt road, with trees and bushes in the distance, and a pond and waterline behind
# caption: the stairs that go up through a jungle like trail
# caption: many dais and other flowers
# caption: blossom trees in spring, photographed with blue sky
# caption: the harbour with many boats and mountains in the background
# caption: an old wooden building in the middle of a grassy field
# caption: a flower with a blur in the background
# caption: some small flowers in the woods
# caption: a blonded blond woman walking down a road
# caption: red flowers in the sunlight
# caption: some flowers with blue sky in the background
# caption: water drop on grass
# caption: a river in the jungle
# caption: a mountain stream near the village of kran
# caption: a path leading through the forest
# caption: an empty building surrounded by leaves
# caption: a tree in a street scene
# caption: purple flowers that look very pink
# caption: two white flowers on a window si
# caption: red leaves on the ground
# caption: a dog that is in the field
# caption: an abstract green marble texture
# caption: crocus flowered on the ground
# caption: a baby boy wrapped in a hat, curled against an old blue bucket, wrapped with cribe
# caption: cherry flowers
# caption: yellow flowers on the plant
# caption: dawngael house in a flower field
# caption: some ice and some flowers
# caption: some people and the water
# caption: crocum - tuquanensis and their flowers
# caption: flowers with some small, pink colored petals
# caption: an asian cherry tree
# caption: some flowers that are growing in a garden
# caption: the dublin cathedral in ireland
# caption: flowers in the middle of the field
# caption: some cherry trees near the water
# caption: a bird in a tree
# caption: a road surrounded by trees
# caption: a cherry blossom on a tree
# caption: white roses
# caption: someone holding a white rose
# caption: a river in the woods
# caption: a blooming tree
# caption: leaves on a tree
# caption: wildflowers
# caption: white flowers in the center of a wooden table
# caption: some small flowers in the ground
# caption: flowering branches
# caption: the word'orph'printed on top of a white book beside with yellow tulipip
# caption: a fountain in the center of a small city area
# caption: a man walking in the sunset
# caption: leaves, the branches are full of bright green foliage
# caption: some white daies in a field
# caption: dewy grass with water drops
# caption: yellow flowers in a field
# caption: a flower on a branch
# caption: a glass vase with two roses
# caption: moss growing in the gut
# caption: a city from the top of the tower
# caption: a daisy that is growing in the grass
# caption: flowers, a pink flower, and white flowers
# caption: a flower on a tree
# caption: an orange rose
# caption: the sun shining through some trees
# caption: the pink magnolia bloom in bloom
# caption: bleedings
# caption: a shed and trash
# caption: the lavender gardens and its beautiful plants
# caption: a branch with green leaves
# caption: pink blossoms in bloom on a branch with blue sky
# caption: the sakura tree with white flowers
# caption: a park area with many different trees
# caption: some yellow flowers on a hill
# caption: a todd on the garden by julia wilson photography
# caption: the sun behind a cherry tree
# caption: a cliff
# caption: a man sitting on a hill with trees and grass
# caption: an image of the plant with flowers
# caption: pink and yellow flowers with blurred background
# caption: a field with crocys flowers
# caption: some flowers that are pink
# caption: the view from above the lake
# caption: purple flowers
# caption: two airplanes on the runway at helsinki - ludskil
# caption: a small bird standing next to some leaves
# caption: a lake and some trees
# caption: some pink flowers and blue sky
# caption: fields in the summer
# caption: flowers that are blooming around the world
# caption: some pink flowers near a tree
# caption: a bird that is sitting on a branch
# caption: flowers in front of a window
# caption: some flowers on the ground
# caption: the fence behind a tennis court
# caption: pink pe peica peicaa flowers in a woman's white dress and pale beige linen trousers
# caption: some red flowers on a tree
# caption: pink blossoms in bloom along a road in washington
# caption: a path that is overgrown by trees
# caption: a forest path surrounded by green leaves and trees
# caption: purple lila
# caption: a large mansion
# caption: white flowers on the branches
# caption: blue flowers on the ground
# caption: wild flowers in the woods
# caption: blue flowers that are in the grass
# caption: the path at the boardwalk trail
# caption: crocy flowers in the mountains
# caption: a woman in a field
# caption: a road and mountains
# caption: the seed of a danyl plant
# caption: the front view of a row of apartment buildings
# caption: red flower
# caption: blossoms with a blue sky in the background
# caption: an espress cappuo served in a white cup on a marble table
# caption: a woman wearing pink dress
# caption: trees and bushes in the middle of a road
# caption: a wooden pal with flower hearts on it
# caption: tall trees with sun streaming through the leaves
# caption: the branches of the apple tree
# caption: flowers in the middle ages
# caption: pink flowers with blurred background
# caption: the sunlight shining through some grass
# caption: tulips on the flower field
# caption: pink flowers
# caption: the centerpiece
# caption: some animals lying in the grass
# caption: a living room with some flowers
# caption: an blooming tree with pink flowers
# caption: some purple flowers on the tree
# caption: a yellow flower against a blue sky
# caption: a flowering tree
# caption: some baby plants in the soil
# caption: an electric pole in the middle of nowhere
# caption: a vase in front of a white sheet
# caption: roses on the side
# caption: someone's hand and flowers
# caption: a beautiful cherry tree in full bloom
# caption: pink flowers in the background
# caption: a bunch of flowers, tulipops — photo
# caption: people sitting on the ground
# caption: a family with a little boy
# caption: a person holding some flowers
# caption: many yellow flowers on display
# caption: an open field with flowers
# caption: pink flowers and bubbles
# caption: some pink blossoms
# caption: flowers with blue sky in the background
# caption: icicles
# caption: a person in the middle of the road
# caption: some leaves that are in front of a blue sky
# caption: a house in a field full of yellow flowers
# caption: a cluster of mushrooms growing on a tree
# caption: lila blossoms against a grey sky
# caption: flowers and trees with clouds
# caption: some flowers in some green leaves
# caption: a flower that is in the grass
# caption: a red plant with a lot of flowers
# caption: a blue flower with leaves and water drops
# caption: yellow flowers with a green field
# caption: a single purple flower
# caption: some trees with the sky in the background
# caption: a house on a small island surrounded by mountains
# caption: an old tree stump that is rotting
# caption: some flowers in the grass
# caption: the beautiful lake balamata on the shores of lake balamata
# caption: the isle on skye skye skye, in county clare
# caption: a man on the beach looking at an urban area
# caption: a person standing among trees with yellow flowers
# caption: a river and buildings near the town
# caption: flowers and the sky
# caption: flowers with text on it
# caption: flowers on an antique stool
# caption: flowers in a vase
# caption: a tree with pink flowers
# caption: trees with flowers on them
# caption: some flowers in the grass
# caption: some plants and some mountains
# caption: pink flowers on a tree
# caption: a flower crocum in the cemetery
# caption: red flowers and trees
# caption: tuliploa flowers on display at the skagard botanical garden
# caption: some bird in the water
# caption: a flower in the middle of the lotus
# caption: a mountain lake surrounded by white and blue snow
# caption: flowers in the garden
# caption: two models, wearing jackets, jackets and sunglasses
# caption: flowers that have been blooming
# caption: a flower that is blooming on a branch
# caption: a sign with the words'make you happy'and'smile you well
# caption: a tree with pink blossoms on it
# caption: a bouquet with white tulle
# caption: a tree in a field
# caption: violet flowers on the ground
# caption: spring flowers, like crocy - croconsils
# caption: some dried flowers with a blurred background
# caption: a large field
# caption: a factory with many different colored structures
# caption: a small brown and white dog
# caption: pink carnationas scattered on blue background
# caption: some white flowers in the middle
# caption: small white flowers growing through dark brown leaves
# caption: some pink flowers with one bud
# caption: some candi bags on a tree with pink flowers
# caption: some flowers in the sky
# caption: some pink flowers in a field
# caption: an orange field of flowers by luke long for stocks
# caption: two flowers with green and white leaves
# caption: a beautiful woman posing in a sunflower field on her honeymoon trip
# caption: a red leaf on green grass
# caption: a rock in the middle of a body
# caption: a man hiking the trail to a small campground on mt hood
# caption: a flower bud
# caption: tulipin of tulipin in blooming in the garden
# caption: pink tulipys
# caption: some flowers on the branches
# caption: a butterfly perched on top of some flowers
# caption: the red - flowering flowers and bud bud buds at the japanese garden
# caption: some red flowers
# caption: dai dais in the sun
# caption: purple flowers with blue sky in the background
# caption: a bunch of flowers
# caption: a little girl in an autumn park
# caption: some pink flowers on top of a green tree
# caption: mountains and trees during sunset
# caption: a green landscape with hills in the background
# ...
# caption: a skyscraper in the background
# caption: a tree with some leaves and branches
# caption: a boat floating down in the lake
# caption: a woman wearing sunglasses on the street
# caption: limes and salt next to a bottle
# caption: a bird in the branches and tree
# caption: fruit in a basket
# caption: some plants on the beach
# caption: a cat
# caption: a boy and girl in denim overalls
# caption: the farm in uttar, which is very good, you can see some houses on the hillside
# caption: palm trees at the beach with a small pool in front of it
# caption: the forest that's not a home photo by tom mc
# caption: a palm tree that was growing in the sand near the beach of ka'anata on kaua
# caption: a woman in short shorts and grey shirt
# caption: a water fountain with green background
# caption: two small cakes on a plate
# caption: the ocean
# caption: a field of sunflowers
# caption: the beach of a lake
# caption: an orange beach umbrella and sand
# caption: the sun on a lake and some people
# caption: boats on the beach at palapaa, sri, west bengal
# caption: a waterfall with water coming out of it
# caption: a city on a sunny day
# caption: lavender
# caption: the palm trees that line up front of apartment buildings in miami, florida
# caption: a tree and white walls
# caption: a couple relaxing on the grass
# caption: a black and white striped straw hat, a hand - dyed notebook, some sunglasses and pearls earrings
# caption: an outdoor courtyard with stone steps
# caption: a person walking in front of a beach
# caption: a beach with some trees
# caption: a woman sitting by the pool
# caption: a sun shining over a field
# caption: an olive grove
# caption: a pretty pink flower
# caption: grass at sunset
# caption: palm trees against a blue sky
# caption: a lady looking into the sky
# caption: a tropical beach
# caption: a resort with palm trees and a swimming pool
# caption: a palm tree on the beach
# caption: palm trees with a blue sky in the background
# caption: an infinity pool in a beach house
# caption: the ocean, and palm trees
# caption: a village
# caption: the sun rising over the ocean
# caption: a martini cocktail on a table
# caption: a flower with pink petals
# caption: some fire sparks on the ground
# caption: the buildings in the background
# caption: a woman using a pump on her car engine
# caption: five lemons one cut in half and placed on top to the other on white
# caption: the ocean from behind some weeds
# caption: the water and the islands from the boat
# caption: a beach under a tree
# caption: the sky during sunset
# caption: jungle in the jungle
# caption: someone jumping in the water
# caption: an aerial shot of a tennis court
# caption: a beautiful woman standing in the middle of a field of sunflowers
# caption: a person on the beach flying a kite
# caption: someone standing on some rocks
# caption: fishing boats sitting in the sand on the beach
# caption: kilo
# caption: green and white leaves with a large black and white striped plant
# caption: a scarf with a book, sunglasses, and a leaf design on it
# caption: a tree with black leaves
# caption: a man on a boat getting ready to sail, back view
# caption: palm trees and fog
# caption: the dock on the edge of a lake
# caption: some kind of a drone flying in the air
# caption: an abstract art scene, through the wet window glass
# caption: a woman sitting on rocks in the ocean
# caption: someone's hand holding a beverage
# caption: a bison and some trees
# caption: a sandy island
# caption: some fruit and nuts in a bowl
# caption: sunflowers that grow in the field
# caption: purple flowers and a bee that is on a flower stalk
# caption: two girls, one holding a flower and the other watching the sun
# caption: some white flowers that are almost unfring
# caption: a young couple in love
# caption: an old door and window
# caption: the water and mountains
# caption: a kayaking
# caption: a woman in the grass near a swimming pool
# caption: a beach with trees on it
# caption: a house with flowers on the front
# caption: pink flowers
# caption: the sea on the oceanway tour boat
# caption: a beach
# caption: an apple homepod
# caption: the water of a large body of water
# caption: a palm tree against the blue sky
# caption: some red flowers in the garden
# caption: some trees and water
# caption: an outside patio at a beach
# caption: a man staring at the spider web
# caption: an arrangement of flowers laying on a wooden table
# caption: a pool turtle, floating in the water
# caption: the sunset in bali, with the silhouette of a palm tree on a beach at dusk
# caption: the ocean and palm trees
# caption: the back of a woman, in white bikini top at sea, looking away
# caption: a beautiful and elegant home surrounded by nature in south goa
# caption: a palm tree on the beach
# caption: the ocean and sand at an open beach
# caption: the lake of villes, seen from the apartment in provence
# caption: a field and a barn in the distance
# caption: water ripple on the lake
# caption: eucalyptus leaves in a pink background
# caption: a woman that is flying through the air
# caption: someone swimming in the water
# caption: the national mall on an overcasting day
# caption: the view from the boat on the amazon rainforest
# caption: a ferris in an amusement setting
# caption: a small fluffy rabbit sitting in the grass
# caption: different fruits next to each other fruits and ve ve
# caption: a girl standing next to a boat
# caption: water and rocks in a stream
# caption: the sky in an ocean
# caption: palm trees and rocks on the beach
# caption: the basilica of san giorgio mass at florence
# caption: some people walking around a city by the water
# caption: the coastline and sea with waves coming
# caption: a hamer
# caption: the ocean with a boat and palm trees
# caption: grass that looks like they have flowers in them and are pretty in their natural beauty
# caption: purple jao tree in bloom against blue sky background
# caption: many people sitting in the grass in a public area
# caption: palm trees from below and some coconut trees that have been damaged
# caption: three palm trees and some pink flowers
# caption: produce displayed at the farmers market
# caption: people dancing and having partying
# caption: the ocean and the coast
# caption: the lake and mountains with birds flying over
# caption: a woman taken by the same lens
# caption: a woman relaxing in a swimming pool
# caption: a lake with trees and mountains in the background
# caption: an iced drink in a beach chair
# caption: a couple of birds flying through the air
# caption: the back of a man wearing a headset
# caption: an instructor on a rock formation in the mountains
# caption: a beach and some houses
# caption: a body of water in the middle of the water with small white clouds and a blue sky
# caption: a beach from above
# caption: a plant with white flowers
# caption: someone underwater diving
# caption: a beach through the bushes
# caption: kids and men in a zoo
# caption: a single tree growing out of the ground
# caption: a girl jumping off a dock
# caption: some trees by the ocean
# caption: the sun shining bright
# caption: a beach scene with the sun setting on the ocean
# caption: sandcastles at the beach
# caption: the beach and cliffs of capo do caba, near lagos, spain
# caption: sunflowers
# caption: a large palm tree
# caption: a rock cliff
# caption: stairs in an empty building
# caption: a lifeguard unit on a beach in jamaica
# caption: a baby in the sand playing with toy
# caption: the sun setting through some wild oats
# caption: three pineapples on a white background
# caption: a dog looking at the camera
# caption: watercolor hand prints on paper with words that read to learn what is your identity
# caption: two women on the beach
# caption: some glass bottles with writing
# caption: straw umbrellas on the beach
# caption: the beach, taken from a drone
# caption: a crowd outside a windmill
# caption: a beach with people relaxing on it
# caption: the stalks in a field
# caption: the beach with lots signs on it
# caption: people in the beach at sunset
# caption: people and palm trees in the background
# caption: an outdoor swimming pool
# caption: green plants with sunlight streaming through the leaves
# caption: a cabin in the mountains
# caption: a small town square with buildings
# caption: a bunch of palm trees
# caption: the beach from above
# caption: a field with trees and pops in the fore
# caption: a field with trees in the background
# caption: some palm trees under the clear blue sky
# caption: beach toy cup
# caption: people on the beach in sunset
# caption: the self electric scr
# caption: a beach with palm tree
# caption: the sea with bubbles
# caption: a sunset
# caption: people on the beach
# caption: a beach with many people
# caption: palm trees and blue sky
# caption: palm tree
# caption: people relaxing on the beach with rocks in the background
# caption: boats parked in a harbor
# caption: someone standing on a beach
# caption: palm trees
# caption: water with several ducks in it
# caption: the beach with chairs and palm trees
# caption: wheat in the fore
# caption: the pool at myeon hotel in ph that was shot on the trip to the ph beaches of thailand
# caption: beach huts
# caption: a jellyfish in blue water
# caption: someone holding a wooden plank, with their feet crossed with a brown shoe
# caption: some people playing in the sand
# caption: a sprinting machine in the field
# caption: some beautiful red flowers
# caption: the letters con are made in red font
# caption: some palm trees against the sky
# caption: a young couple kissing near the sea
# caption: the beach with people at the edge of the water
# caption: rocks and buildings by the ocean
# caption: a woman walking on the beach
# caption: palm leaf against a clear blue sky
# caption: the inside of a bathroom with shadows
# caption: the mountains from a boat
# caption: a dog on the grass
# caption: a fish from the water
# caption: some palm trees with no leaves
# caption: a young man sitting on the edge of the cliff, wearing shades in the background of a city and the blue sky
# caption: a young boy playing on the beach
# caption: a man holding a rope while climbing
# caption: a woman in a car waving her hands
# caption: some palm trees on the beach
# caption: palm trees against the sky
# caption: the beach near palai
# caption: a boat sailing through the water
# caption: people taking a bath in a body of water
# caption: someone reaching their hand out of the window
# caption: the city
# caption: some rocks and green plants on a beach
# caption: a bridge on a small canal
# caption: a town in the mountains
# caption: the beach with sun umbrellas in a row
# caption: people swimming in the pool and trees
# caption: the palm trees
# caption: a small island with buildings on it
# caption: someone standing alone on the beach
# caption: people swimming and having a fun time
# caption: fruits on the ground
# caption: the back of a woman
# caption: the beach with palm trees
# caption: a beautiful lady leaning on a large pine tree
# caption: wild flowers in the desert
# caption: an old car parked in the beach
# caption: young woman in purple lavender fields
# caption: sunflowers in the field
# caption: the top view of a green palm tree with white flowers
# caption: a palm tree against the blue sky
# caption: the mountains in the bavarian alps
# caption: a window with some light on
# caption: a pretty girl sitting on a lifeguard chair
# caption: a man with several items on top of a car
# caption: tile wall
# caption: a small tropical town and a body of water
# caption: palm trees against the sky
# caption: a tropical beach scene
# caption: the alps in switzerland, taken on an open - air photo of the alps in cloudy weather
# caption: the texture on a green palm leaf
# caption: a small dog that is in a kayak
# caption: sunset
# caption: the cyclist that has been taken on his knees in the paralympics track cycling race
# caption: some hills with snow
# caption: a woman sitting next to the ocean
# caption: the golden gate bridge at night
# caption: a woman running through the sand
# caption: the setting sun in a field of grass
# caption: a trash can on the ground
# caption: an island with green water
# caption: a woman laying on the ground wearing a dress and hat
# caption: an island in the greek islands
# caption: palm trees
# caption: mountains and water with clouds
# caption: a woman in her bathingro
# caption: the beach in front of a blue sky
# caption: some palm trees against a sky
# caption: an old, wooden hall with the light coming from the ceiling
# caption: a dragon fly
# caption: two coconut trees near the ocean
# caption: the village with some flowers
# caption: colorful beach huts on the beach
# caption: some people and water on the beach
# caption: a person floating in the water
# caption: the top end of palm leaves against a blue sky
# caption: a little boy walking along a beach path in the dunes near portmeier, western normandy
# caption: flowers growing in the grass
# caption: the colorful flags in front of the national capital of tibet
# caption: palm trees taken in a very blue sky
# caption: a kid swinging
# caption: the beach with trees and water in the background
# caption: a beautiful beach view taken from above
# caption: a beautiful woman on the beach wearing her own
# caption: some green leaves on the branches
# caption: some flowers in a vase
# caption: a man and woman who are standing in water
# caption: a pine branch in front of the ocean
# caption: me laying on an inflatable in the pool while i'm napping
# caption: boats in the water near a pier
# caption: a trail with lots of trees in the background
# caption: friends playing violin and singing around the campfire
# caption: leaves that is in a plant
# caption: a tree at sunset, with the sun peeking through the tree
# caption: a person standing in the fog in a forest
# caption: flowers on the side of a fence
# caption: many people on a beach
# caption: someone throwing colored powder on him
# caption: a man floating in the water
# caption: an arid surface with soil
# caption: an exterior in black with sky and clouds
# caption: someone swinging down on a palm tree
# caption: a sandy beach with many small boats and buildings
# caption: the ocean at dusk
# caption: people having lunch in an alley
# caption: a pathway surrounded by lush gardens at the park
# caption: a mountain with water and a mountain peak
# caption: a pineapple growing on the beach
# caption: the beach with many lounges and sun umbrellas
# caption: children playing on the beach at cali de agua in tuqui on the south coast
# caption: the flower girl holding flowers
# caption: an old wooden bench with ocean view
# caption: a group of people on a beach
# caption: a man running
# caption: a beautiful garden rose
# caption: a tropical beach with palm trees
# caption: a banana tree that is full of fruit
# caption: a beach scene with the sand being blown by a storm
# caption: the trunk forest showing a wide canopy and some bare birch trunks
# caption: some people by the ocean
# caption: an evening sky with rain and storm clouds above a body of water
# caption: two cocktails with a beach towel
# caption: the beach
# caption: a woman enjoying her time with ice
# caption: a beach area at the water's edge
# caption: a baby on the beach playing with the sand
# caption: the road that was closed to traffic and blocked a section of highway
# caption: the destroyed jeans shorts
# caption: a bodyboard boat in fiji
# caption: a man swimming
# caption: palm trees in front of a body of water
# caption: a view on the slopes of the otago mt panorama peak
# caption: a park with palm trees and people in it
# caption: palm trees against a blue sky
# caption: the ocean with a boat mooreing on it
# caption: two cows in the field with a man walking along
# caption: houses and palm trees in the water
# caption: some green plants outside
# caption: some trees, bushes and plants in the middle of an indoor jungle
# caption: the ocean near a grassy area
# caption: white houses in the hills
# caption: an oyster being its way into the sand
# caption: a sunflower bloom on the ground
# caption: an open book sitting on top of a tree stump
# caption: palm trees against a blue sky
# caption: the beach with some palm trees and people on it
# caption: two palm trees in the air
# caption: the beach in fiji, australia
# caption: someone in the water
# caption: a clear blue sky
# caption: the sky
# caption: a beautiful meadow with many wild flowers

# %%
# Run below code after restarting the session
from models.blip import blip_decoder

image_size = 512
images, image_names = load_demo_images('/content/season_images', ['fall', 'winter'], image_size=image_size, device=device)

model_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth'
model = blip_decoder(pretrained=model_url, image_size=image_size, vit='base')
model.eval()
model = model.to(device)

text_folder = '/content'
output_file = 'season_captions.txt'
output_file_path = os.path.join(text_folder, output_file)

with open(output_file_path, "a+") as f:
    with torch.no_grad():
        for i, image in enumerate(images):
            caption = model.generate(image, sample=True, num_beams=3, max_length=40, min_length=5)
            print('caption: '+caption[0])
            image_name = image_names[i]
            f.write(f"{image_name}, {caption[0]}\n")
# Out:
# fall images loaded
# winter images loaded
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: the outside of a building with the top section of a parking lot to the left
# caption: fall leaves and weeds along the trail
# caption: the leaf in autumn
# caption: the dirt road leading to a small hill and village
# caption: vineyards in autumn with hills in the background
# caption: a city from the outside
# caption: a menu and magazine
# caption: a bunch of different types of pumpkins
# caption: the river with water reflections
# caption: a leaf
# caption: a fall scene with colorful foliage
# caption: the green lake, surrounded by colorful autumn foliage, from above
# caption: a tree that is blowing on the wind
# caption: someone holding a leaf on their left hand
# caption: a courtyard with benches, potted flower pots and plants in the ground
# caption: a man with his head in the air looking seriously at the camera
# caption: the waterfalls of mulang falls, cebu - photo courtesy fwf com by fg
# caption: an old train with graffiti written on it
# caption: leaves on the grass at sunset
# caption: some water near a dock
# caption: a dark room with stairs and fire escapes
# caption: a small boat on the water
# caption: mountains and trees with clouds
# caption: flower petals and leaves on the ground
# caption: a temple in china
# caption: a park with some trees and leaves
# caption: a house in the middle of nowhere
# caption: an island with orange trees in the water
# caption: someone standing in the forest
# caption: some mountains and houses
# caption: an autumn sweater and a coffee
# caption: a mountain with clouds above
# caption: a mushroom growing in leaves
# caption: a park bench in autumn
# caption: the lake and trees on a sunny day
# caption: the small river and mountains of the sierra sierra
# caption: an autumn leaf hanging from a clothes line in front of blue sky
# caption: fall leaves
# caption: yellow leaves
# caption: the river flowing through a forest
# caption: a leaf strewn path next to a building
# caption: a classic car driving through the woods
# caption: the house on a mountain
# caption: a fence and a field
# caption: an empty highway with the road winding
# caption: two people holding hands looking out at the water
# caption: the night sky with stars above it
# caption: trees with fallen leaves and fall color
# caption: mountains in the distance, with mist, clouds and water in the photo was taken from the top of the mountain
# caption: a stagna in the dark forest
# caption: a tree that is on the shore of the sea
# caption: someone holding a coffee mug
# caption: fall trees with reflection
# caption: leaves and snow on a white surface
# caption: a mushroom
# caption: a young girl walking through the woods
# caption: a hill with fall colors and a blue sky
# caption: some trees, water and grass
# caption: aspen trees that have turned their leaves for autumn
# caption: paper stars and book pages
# caption: frost on a fall leaf
# caption: some pumpkins in the grass
# caption: an oak tree with the autumn leaves changing colors
# caption: a creek in the rainforest
# caption: the golden and silver leaves, nuts, and nuts
# caption: a green plant with lots of pine fr
# caption: the 2020 ford edge in front of a flooded street
# caption: the ocean and the grass of a landscape
# caption: a plate of food
# caption: a young woman in a field holding two oranges in her hands to show their emotions
# caption: a person with their feet in the air over a pile of leaves
# caption: plants with rain droplets
# caption: a fallen maple tree
# caption: leaves scattered on the sidewalk during the autumn storm, in new york
# caption: two acotus
# caption: a person standing on top of a mountain on the foggy mountains in ireland
# caption: a foggy, filled forest
# caption: a tree with some bikes in front
# caption: a girl wearing white pants standing in the woods with green foliage surrounding her and looking at the camera
# caption: cactus pots in green
# caption: some food on a table
# caption: train tracks
# caption: a colorful fall leaf
# caption: trees in the fall season
# caption: trees and leaves that is on display
# caption: a foggy scene with dead trees
# caption: someone walking on a street
# caption: someone taking a picture
# caption: the sun shining through the leaves
# caption: the side of an orange and a bunch of green peppers
# caption: a building with a tree in the fall
# caption: a young woman
# caption: some flowers in the dark
# caption: an electric car in autumn
# caption: pumpkins stacked on a tree stump
# caption: leaves scattered across the walkway at an atlanta arboretum
# caption: the mountains of the douro de gordal
# caption: four glasses with three different types
# caption: an image of some mushrooms
# caption: the sun shining through trees in the park
# caption: pumpkins with flowers and teacup
# caption: a mountain and trees with the fog
# caption: child holding a pumpkin during halloween at westport nursery school in milford, ma
# caption: pine, fir, and pine cones with some red berries
# caption: a girl on the street wearing a watermell
# caption: various items laid out on a wooden table
# caption: balloons at the wedding reception
# caption: the harbor as seen from a boat
# caption: a field of sunflowers and a bug, taken in july 2016
# caption: leaves laying on the ground
# caption: someone putting a golf ball
# caption: a purple and orange pumpkin
# caption: some trees and leaves on the ground
# caption: an old house in the field
# caption: trees with many colors
# caption: a leaf that is changing colors
# caption: an aerial shot of a tractor plowing the field
# caption: green and red apples
# caption: the grand te and the mountains, from the snake lake
# caption: autumn leaves sitting on a wooden deck
# caption: fallen autumn leaves in autumn
# caption: an aspen tree in fall
# caption: a highway going down from the mountains into the ocean
# caption: dew droplets on a leaf
# caption: a bunch of red and yellow autumn leaves
# caption: a very small stone building
# caption: the waterfall at murchia waterfall national park
# caption: an old tree with a bird perched on it
# caption: two people walking down a path
# caption: a mountain covered in fall foliage
# caption: a tree that is next to some sheep
# caption: trees and water in the middle of a forest
# caption: someone backpack review - backpacks
# caption: a tree lined street and sidewalk
# caption: a stream flowing through the woods
# caption: autumn trees in the middle of an aerial shot
# caption: some trees and some leaves
# caption: a waterfall with a few leaves falling off it
# caption: sugared biscuits
# caption: someone's hand holding a ras
# caption: the view from my seat at big bear camp, one of my favorite things in the north fork
# caption: a church and the sky
# caption: two jars filled with dried leaves and some dried maples
# caption: a girl holding a lantern, with leaves in front
# caption: mountains in the clouds
# caption: an abandoned house on the edge of water with mountains in the background
# caption: a house surrounded by trees
# caption: small orange and red berries
# caption: the path to the water
# caption: some plants in the woods
# caption: a person taking a picture with their cell
# caption: some water and trees
# caption: an orange flower on a black background
# caption: leaves, rocks and rocks in the water
# caption: some flowers and an i love card
# caption: the mont val in the background of the trees
# caption: wooden blocks spelling the word'pumpkin spice and things '
# caption: some water with green plants in the background
# caption: an old red brick building
# caption: trees in a field and fence
# caption: autumn leaves in bright orange color
# caption: leaves on the wet ground
# caption: some yellow and red leaves
# caption: three pumpkins in the middle one is orange and the other is brown
# caption: a tree reflection in a puddle
# caption: some birds in the water
# caption: a hiker with his back to the camera
# caption: a young man standing in the middle of a leaf strewn wooded area
# caption: a leaf on the road
# caption: an waterfall surrounded by trees
# caption: some leaves on a branch
# caption: a building surrounded by leafy trees
# caption: trees covered in snow in the mountains
# caption: two chairs sitting in the leaves
# caption: an empty red bench in the fog and the autumn leaves all around it in foggyen
# caption: autumn leaves and moss
# caption: a maple leaf sitting on a wooden bench
# caption: a flower in snow
# caption: a forest covered in colorful fall foliage
# caption: a bright orange maple tree leaf against a blue sky
# caption: a woman looking down at the treetops in norway
# caption: a bottle of wine and autumn leaves
# caption: power lines in front of some trees
# caption: mini pumpkins
# caption: a forest filled with trees and white leaves
# caption: someone taking a photo
# caption: the fall colors in lake of eagle
# caption: an aerial view of autumn foliage
# caption: a table with apples and a framed
# caption: the city police car parked in front of the entrance of the chicago police headquarters
# caption: a wrist watch on the finger of a person holding their hand
# caption: a bunch of small yellow and orange flowers
# caption: a cake with spspy and black frosting
# caption: a street in the woods
# caption: a person in a truck
# caption: an autumn morning on main st, taken by my mother
# caption: a scare head sitting in a garden on a pile of leaves
# caption: a person walking through a foggy forest
# caption: an extended girl standing outside in the woods holding her camera
# caption: the face of half dome, yoaroi and the trees behind
# caption: someone taking their ice cream cones
# caption: a woman looking up at a tree in the woods
# caption: a long haired dog in the woods
# caption: trees lined with orange leaves, walking through the foggyder park
# caption: autumn leaves against a blue sky
# caption: someone sitting on the bench
# caption: many fishes swimming at a dock
# caption: some trees that are changing colors in the water
# caption: an apple pie on a glass plate
# caption: a beautiful young girl dressed up as witches
# caption: a horse that is standing
# caption: two cats playing in the fall leaves
# caption: someone wearing tennis shoes on the ground
# caption: an empty mountain road in the morning with a sunset - free images from fs and foto for sale
# caption: the band's vocalist, hannah stauter
# caption: the sun setting over mountains
# caption: a young man running along the road towards a sunny summer afternoon
# caption: an empty country road with fallen trees in fall
# caption: a cat on the ground
# caption: the mountains in the fall
# caption: a person walking through the woods
# caption: a view from a mountain top
# caption: trees on the shoreline
# caption: an empty highway in the fog
# caption: a mug that is being filled with coffee
# caption: an aerial view of a forest
# caption: some very umbrellas hanging over houses
# caption: buildings and street with trees
# caption: an island with autumn trees near it
# caption: a bird's nest on the branch of a tree
# caption: trees reflecting in a lake
# caption: the holocaust at sunset
# caption: an outdoor playground with a bench and trees
# caption: sunflowers in blooming at the farm
# caption: flowers inside of a vase
# caption: kids celebrating halloween with a skeleton statue
# caption: the hut bike helmet
# caption: a mushroom with leaves in the background
# caption: some water fall waterfalls in canada
# caption: a white mushroom on the ground
# caption: pumpkins
# caption: an open book
# caption: a boat traveling down the canal in san
# caption: some benches with some trees in the background
# caption: different drinks and cids on display
# caption: orange and yellow pumpkins
# caption: the river in the fall
# caption: a road with fog and some trees
# caption: leaves on a plant with a black background
# caption: an empty street
# caption: leaves in the grass
# caption: a red and white pagoda
# caption: the first day of the first days with the kids on the green hat by my family
# caption: a beautiful autumn day with the fog and fog rolling off to reveal the autumn colors
# caption: a man standing at the bottom of a waterfall
# caption: mountains and a cloudy sky
# caption: christmas decorations in shelves
# caption: the mountain peaks taken from below
# caption: mountains, road and a river at sunset
# caption: the forest in the dark
# caption: a woman smiling
# caption: a beautiful sunset in tambuk on kole beach near tauking - kamu, kalha island, auckland new
# caption: an empty parking lot
# caption: the sky behind leaves
# caption: the mountains and rocks on the shore
# caption: the full moon taken from across the sky on a clear night
# caption: yellow maple leaves against a blue sky
# caption: a young woman holding out her book with a flame coming out from her mouth
# caption: some pumpkins in a white vase and candle
# caption: a man drinking something out of a cup
# caption: red and brown leaves arranged in a triangle shape on a white surface
# caption: apples on the ground
# caption: several pumpkin tartilltas on a wooden table
# caption: water droplets in the woods
# caption: a woman sitting down on the steps looking down into a valley
# caption: a mushroom sitting on the side of a tree
# caption: fire burning into the camera
# caption: crans in a basket
# caption: some plants on a blur background
# caption: the leaves that i use to cover a fall photo
# caption: the city taken by an amateur photographer and its window view
# caption: a woman with a smokestak and her hand in the air
# caption: the moon in the night sky
# caption: the tower at the center of granada, spain
# caption: an orange and black scarf with the word'best'on it
# caption: the autumn sun behind a tree
# caption: the sky over a corn field
# caption: autumn leaves, in the dark
# caption: a wooded with trees and rocks
# caption: a mason jar with water in it
# caption: the jeep's exterior
# caption: autumn foliage on the trees, with leaves scattered
# caption: an empty bench and some leaves
# caption: a boat at the shore with leaves floating in it
# caption: leaves and berries on the plant
# caption: leaves on the branches
# caption: a tree in the fall
# caption: a todd running down a path
# caption: fall leaves and notebook on a black background
# caption: an apartment building from below
# caption: some kind of red leaves
# caption: autumn leaves hanging from a tree
# caption: a wooden bridge in the woods
# caption: trees in the fall and leaves in the fall
# caption: two bicycles parked on the side of a road
# caption: a river
# caption: a house decorated for halloween
# caption: fall trees, parked car and houses
# caption: some apples on a wooden pal
# caption: some white, green and brown libina
# caption: yosem in yosem yossm yosem yosem yosem yossm yosse
# caption: the ocean
# caption: a woman in the forest looking at the camera
# caption: some leaves on the ground
# caption: some food and an orange
# caption: some trees and mountains in the background
# caption: a white church with red door and steeple
# caption: two park benches covered with leaves on the ground
# caption: the 1967 ford gtp sitting on the road next to a car in the fall trees
# caption: a scare with an owl face on a wooden stick
# caption: a girl wearing a witch mask
# caption: some trees with colorful leaves around
# caption: autumn foliage at my grandmother's yard
# caption: a grassy field with mountains in the distance
# caption: the sun shining over some crops
# caption: two people wearing flacets and flas
# caption: the food on top of a basket
# caption: a wooden pumpkin sign with paper flowers and the word welcome on it
# caption: tomatoes and garlic in crates
# caption: flowers on top of a cake
# caption: a cup of tea and leaves
# caption: some squashs and pumpkins
# caption: the words happy halloween spelled in black and white
# caption: red leaves against the sky
# caption: trees in the middle of a park filled with fall leaves
# caption: a person standing in front of a waterfall
# caption: some fall leaves
# caption: autumn, fall leaves
# caption: some purple flowers
# caption: the yose and yo yos
# caption: a small island with red and yellow trees in the middle of a river in finland
# caption: some flowers that are pink
# caption: an old homestead near the town of tupea
# caption: a water mill
# caption: snow covered trees by the river
# caption: a person sitting in a chair
# caption: an empty path through the forest
# caption: an aerial view of the town of gondoch
# caption: a banana plant
# caption: a woman standing outside wearing the new pencil skirt in light grey, brown and black, with thigh high heels
# caption: a road in the mountains
# caption: mountains on top of eachothy mountains
# caption: a child in a red sweater that says love is in the air
# caption: fall trees in a park
# caption: the trees from an otherwise distance, on a grassy slope
# caption: a flower
# caption: three red leaves with the sun shining through them
# caption: the lake in autumn
# caption: an outdoor bench
# caption: waterfalls in the jungle
# caption: the sun shining through trees
# caption: some red and yellow leaves
# caption: a woman with long red hair, in a denim jacket and jeans looking away to the road
# caption: a road and some leaves
# caption: two dogs playing in the woods
# caption: an autumn river in the smoky mountains
# caption: a maple leaf covered with ice
# caption: pumpkins in a pile
# caption: a small mushroom sitting in the grass
# caption: a dog sleeping in the shade
# caption: a bench under an autumn tree
# caption: a raspkin - rhuk smoothie
# caption: a yellow leaves
# caption: rose flowers on white
# caption: an airport with stairs that are closed
# caption: two people walking down a trail
# caption: the front of an old log cabin
# caption: someone holding up an autumn leaf
# caption: someone looking down a street
# caption: a plant with lots stems in it
# caption: a frog in water with an open mouth
# caption: fall leaves, acxpls and pine cones on the ground
# caption: some pretty reflection
# caption: mountains with clouds and trees
# caption: an abandoned bridge surrounded by fallen leaves
# caption: an outdoor market with many different types of pumpkins
# caption: the view from the mountain
# caption: some very cloudy clouds i just liked watching this as a sun setting down behind the clouds
# caption: a woman walking on a trail covered with fall leaves
# caption: some pumpkins
# caption: palm branches and flowers
# caption: some food that is on a wooden plate
# caption: the edge of a rock face
# caption: the mountain top surrounded by red flowers and greene and trees
# caption: torta pasta with pesto, tomato, and garlic on a plate
# caption: a lake surrounded by fall leaves
# caption: an autumn wreath on black
# caption: a woman dressed as a mada from the super hero
# caption: a man that is walking
# caption: a beautiful fall landscape
# caption: pumpkins and squash, surrounded by mulchs
# caption: a river that looks like a lake
# caption: a woman smiling while standing in the desert
# caption: a branch covered in autumn foliage
# caption: a forest with colorful leaves
# caption: orange flowers on the ground
# caption: a cup, coffee and a blanket on a table
# caption: the sun shining on a rock
# caption: an iced coffee drink with whipped and whipped
# caption: leaves that are covered in water
# caption: dried rosemary in a basket with other things nearby
# caption: someone holding a mug with coffee
# caption: an autumn scene of some trees
# caption: the view from the top of a hill
# caption: a lake in the wilderness with trees
# caption: trees covered in fog
# caption: an empty trail with trees and leaves on it
# caption: the creek near the waterfall in the canyons
# caption: a road near the town
# caption: a single leaf on a rock
# caption: a hill with fall foliage
# caption: leaves and branches
# caption: the mountains and trees on the left side, with a clear blue sky on top
# caption: a tree with yellow leaves
# caption: some trees looking up
# caption: the road in the middle of an autumn forest
# caption: a road in the fog
# caption: a woman in a parka by a river with trees and rocks
# caption: a person holding an orange pumpkin
# caption: a leaf in some gravel
# caption: the sun setting over the mountain
# caption: a baby wolf dog lying on the ground
# caption: a park with cars parked in the grass
# caption: a mushroom growing near a moss covered rock
# caption: some leaves with the background blurred
# caption: a man and woman sitting together with their skates
# caption: oranges and other ingredients on a wooden table
# caption: the city from across the trees
# caption: apple pie with an empty basket on the table
# caption: leaves falling off of the wood floor
# caption: fall leaves, candles, and tea on the table
# caption: the water with clouds in the sky
# caption: a blue leaf is shown in the fore, but not visible on a bunch of dead leaves
# caption: a coffee cup and two cups on a wooden table
# caption: a mountain in the background
# caption: leaves in the dark with their lights shining
# caption: a roof full of tiles
# caption: a city street in the daytime
# caption: a woman in a grey sweater standing in front of red flowers
# caption: a road and trees
# caption: a couple in the field at sunset
# caption: an outdoor area with an orange glow shining brightly into the sky, surrounded by apple trees
# caption: the mountains in autumn
# caption: the trees in the woods
# caption: an empty highway with trees in the background
# caption: palm trees and a sidewalk
# caption: a sign by a trail
# caption: a woman's hand in autumn
# caption: a small plant on a dark background
# caption: a forest path
# caption: a man with long brown hair and a goateely smile
# caption: a tall building surrounded by fall leaves
# caption: the thanksgiving tablescape
# caption: a halloween pumpkin and a ghost on the ground
# caption: a squash vegetable with seeds
# caption: a trash bin on the beach
# caption: some plants in the sky
# caption: plants with pink flowers in the background
# caption: an island in the water with a small boat on it
# caption: the sun shining through the grass on the other side of a small creek in the back side, mountains are visible behind
# caption: the bow bridge taken from a boat on a river in central park
# caption: the inside of a flower
# caption: an aerial view of a downtown suburb
# caption: the mountains and the lake
# caption: the night with some snow
# caption: a man riding his bike through some trees
# caption: rocks and water next to a tree
# caption: the man who has just reached the summit of big sky mountain in jasper, colorado
# caption: leaves and red in fall
# caption: clothes and accessories on a grey surface
# caption: shoes laying among the leaves
# caption: a person holding a mug and scarf
# caption: a small city with houses
# caption: a river in the woods
# caption: dried snacks
# caption: a fence that is overgrown with grass and debris around it
# caption: clouds and a sun in the sky
# caption: flowers next to a watering pot
# caption: pumpkins with small eyes
# caption: fallen leaves laying on the sidewalk
# caption: the waterfalls of iguara falls
# caption: two train cars driving on a bridge
# caption: some mountains in the clouds
# caption: mungrimum flobinosa flowers
# caption: a house and a street
# caption: some grass near the field
# caption: trees in the mountain with sunlight shining through the trees
# caption: some people going on the road to get on a motorcycle
# caption: an orange bi bike on a path lined with leaves in the autumn fall stock photo
# caption: a single autumn leaf in the forest, red leaf, fall photography
# caption: flowers that are in the fog
# caption: a woman on her phone and drinking coffee
# caption: a lake with a mountain in the background
# caption: an apple in a basket on the ground
# caption: someone lighting a candle that reads
# caption: a couple standing in the woods
# caption: a tree that looks like it is growing in the ground
# caption: mountains and trees in the fore
# caption: a young girl crawling down the sidewalk
# caption: three mushrooms sitting on the ground
# caption: two cows on the side of a road
# caption: a pumpkin and some hay
# caption: a road winding through a fall forest
# caption: some buildings in the mountains
# caption: boats floating next to the old town
# caption: autumn leaves that are bright red, yellow and yellow
# caption: trees that have turned shades of autumn colors
# caption: two people holding frcks, walking through a field
# caption: some green fruit trees
# caption: a park with lots of trees
# caption: the park in the fall
# caption: some leaves on a bench
# caption: a stream running through the woods
# caption: a wooden walkway that leads to the grass
# caption: muffins on a white plate
# caption: a dirt road
# caption: an autumn forest with a puddle in the middle
# caption: trees with lots yellow leaves
# caption: the top - down thanksgiving spread
# caption: the side of a waterfall in new hampshire, nh
# caption: someone holding a pumpkin
# caption: a very large building
# caption: cake that looks like a fruit cake on a plate
# caption: some water flowing from a dam
# caption: fall leaves laying on the ground
# caption: a castle on the shore
# caption: some kind of strange rock formation
# caption: an old wooden structure
# caption: the famous mirror glass building in london
# caption: the arctic fox
# caption: a mountain in the background with water
# caption: someone's house inside an abandoned cemetery
# caption: an industrial area with a large building on the top of it
# caption: an evergreen forest with sunlight rays
# caption: trees that are fall color in the park
# caption: flowers in a vase with clothes, socks and a mug on a dresser
# caption: tree trunks piled together with the sun
# caption: a large grassy field with trees and a mountain
# caption: some trees with the sky behind them
# caption: the landscape from the tun range
# caption: the apple that came to me - i took to take in for this
# caption: trees with yellow leaves on them
# caption: boats docked at the pier
# caption: the moon is shown with its bright shadow
# caption: a setting sun through the clouds
# caption: a cat laying on a table with black and white decorations
# caption: the camera with a lens
# caption: trees and mist
# caption: trees and a stream of water
# caption: an area with small benches on the ground
# caption: the bell tower from below
# caption: plants and reed in the sunlight
# caption: an aerial view of prague
# caption: mini pumpkins that are white with rust, blue streaks, and light orange, all painted in brown
# caption: a branch with red leaves in the fore
# caption: a boy sitting on an old building
# caption: a wooden wheel and some leaves
# caption: a tree with some yellow leaves
# caption: an unusual looking flower
# caption: the road in the foggy rain
# caption: cotton being spread on the fields of central arkansas
# caption: the woods in fall with yellow leaves
# caption: autumn leaves and foliage with a boke lens
# caption: a woman in a black dress
# caption: some people walking and sitting on benches in a park
# caption: a tiny mushroom growing from the ground
# caption: a vehicle that is parked in some trees
# caption: a lemon with some cut pieces
# caption: a small cabin with autumn leaves and mountains in the background
# caption: autumn leaves in a park
# caption: two mushrooms in the woods
# caption: apples for sale in an open air market
# caption: fall foliage around the waterfall
# caption: mountains with some clouds in the background
# caption: some aspen trees and grass
# caption: the railroad tracks that i used
# caption: someone's hand holding an autumn oak leaf
# caption: leaves on the ground in a park
# caption: a plate of food on top of a table
# caption: a plant with flowers on it
# caption: a sunset setting
# caption: a river in a canyon with autumn foliage
# caption: a boy walking down a dirt road
# caption: pumpkins
# caption: the house with autumn foliages surrounding
# caption: the sun shining through trees in the woods
# caption: a bird that is sitting in the snow
# caption: an autumn scene with yellow trees reflected in the clear water
# caption: a peroprosmaidus pumpkin in the grass with a cloudy background
# caption: the duolo cathedral during sunset
# caption: a house surrounded by trees
# caption: pumpkins with one peeled one on the side and the other laying on a wooden cutting board
# caption: a lake in the sunset
# caption: red leaves with yellow, and brown leaves
# caption: a car interior with an open door
# caption: christmas decorations on a decorated tree
# caption: the 2017 nissan titan truck on a mountain path
# caption: some mountains and trees by water
# caption: the ground covered with autumn leaves
# caption: some evergreen branches
# caption: a young woman in the fall leaves
# caption: a little girl painting
# caption: a girl standing in a field
# caption: a woman sitting under a red tree, with leaves falling on the ground
# caption: leaves and a tree in the fall season
# caption: a young girl with autumn flowers in her hands, she is dressed up in witch costume
# caption: a winter table setting, christmas decor and decor
# caption: a leaf held in a hand
# caption: an aerial view of the forest and road
# caption: a little baby mouse in some autumn leaves
# caption: an outdoor park with a boat
# caption: someone looking up in the grass
# caption: leaves on the ground and the brick
# caption: a yellow leaf in the sunlight
# caption: my cat sleeping on my bed with my laptop, phone, and the camera next to me
# caption: a street in the city
# caption: some food and people eating
# caption: some trees in a lake
# caption: pumpkins in a pile
# caption: a frozen sundae milk tea
# caption: an aerial view of the beach and forested hills
# caption: a man sitting down
# caption: the top of a mountain
# caption: autumn trees that are not covered with leaves
# caption: some apples with flowers in them
# caption: two orange balloons on grass
# caption: red autumn leaves on wood - image gratic stock footage
# caption: water
# caption: some birds in the water
# caption: a young girl in a pile of leaves
# caption: an old church on top of a mountain
# caption: leaves on the ground
# caption: a green tractor driving through the fields
# caption: leaves against the sun
# caption: fall foliage in the backyard
# caption: a woman posing in front of the brooklyn bridge
# caption: boats and flowers in the lake
# caption: leaves floating in a lake
# caption: leaves, tree and pumpkin
# caption: fall foliage, lake with boats and buildings
# caption: a person standing on a hill looking out at the view
# caption: some leaves on the tree
# caption: leaves on the ground
# caption: fallen leaves on the ground
# caption: fallen branches in the woods
# caption: a coffee cup and teddy
# caption: an old boat window
# caption: a dog and pumpkins
# caption: trees in the woods
# caption: a mountain in the sunset
# caption: a single goat on a hill
# caption: a red leaf on a branch
# caption: someone holding up an orange, green and red autumn leaf in their hands
# caption: autumn foliage
# caption: a dock in the sunset
# caption: some trees in the middle
# caption: some leaves with the color
# caption: an autumn tree near water
# caption: the word su on a white surface
# caption: a girl standing in the woods
# caption: an old building and a blue sky
# caption: the legs on the ground in front of an image of a city with lots clouds, and a person wearing a pair of shoes
# caption: a beautiful fall day on a residential road
# caption: an orange halloween egg that has been carved into it with a hole cut out and faces out
# caption: the roof top and sky
# caption: leaves on top of each other leaf
# caption: a person riding a bike on a street
# caption: the moon taken by nasa astronaut
# caption: an empty trail through the woods
# caption: waterfalls and trees in the fall
# caption: a dog walking by a boathouse
# caption: an ocean dolphin is seen in a google search
# caption: fallen and old looking leaves in the ground
# caption: some buildings and some trees
# caption: an old man cutting wood
# caption: a flock of birds flying
# caption: some scare heads
# caption: a squirrel in the leaves
# caption: a letter spelling from the word thankful
# caption: the blood moon on april 7, 2019
# caption: a beagle puppy, a black - capped beagle and a brown - haired beagle mix pup are on a trail of
# caption: a lot of pumpkins sitting on the ground
# caption: apples for sale at the farmers market
# caption: a single line on a street
# caption: a street light near some trees
# caption: autumn in the mountains of a forest
# caption: an autumn scene with the woods and mountains in the distance
# caption: glowing halloween pumpkins at night
# caption: two glowing jack and jack pumpkins
# caption: birch trees and some birds
# caption: a magazine on a green plate next to a leaf
# caption: a fox in the dark
# caption: an orange pumpkin in a black background
# caption: the light house at st simon
# caption: the forest in the fall with trees and cloudy sky
# caption: cran cran sitting on top of a wooden table
# caption: the classic cashmere coat in butterburst wool with coffee in hand
# caption: the fall colors at mirror lake in banyansky, styriat, ta
# caption: a leaf with a light reflection
# caption: the road surrounded by trees in autumn
# caption: nuts on top of a wooden table
# caption: white pumpkins that have been harvested
# caption: an autumn leaf
# caption: half dome mountain in yoakamee valley
# caption: an older car, taken from the driver side
# caption: the city skyline and the bridge that runs through a canal of tran son river, hanoi
# caption: a fog over water and trees
# caption: some people walking down a sidewalk
# caption: a bride holding her hat
# caption: the sun setting in the clouds
# caption: a single fall leaf with a blue sky in the background
# caption: a woman wearing sunglasses in the sea and enjoying her stay
# caption: two children in silhouette in front of the ocean at sunset
# caption: a kid writing in doodle on paper
# caption: an empty road through the forest
# caption: an apple tree
# caption: a green tractor in the middle of a large field with a yellow spray gun spraying it
# caption: two friends sitting on a mountain overlooking a scenic fall scene
# caption: some leaves on the tree
# caption: fall leaves
# caption: the blue lake of wadi in oman
# caption: an exhibit in a museum showing human skulls
# caption: a building lit up by the light of a neon sign
# caption: a street with old buildings
# caption: purple flowers growing in the grass
# caption: some leaves against the sky
# caption: mountains that are in the air
# caption: water and leaves
# caption: the mountains with many colorful leaves
# caption: the yellow leaves
# caption: the brown mushrooms that are stored in the basket
# caption: some sorties made out of cardboard
# caption: a woman looking at fjord water
# caption: trees in the mountains with a sky background
# caption: the view from the cable car over heidelberg to heidelberg from the hoe
# caption: a tree standing on top of a mountain
# caption: a girl under a blanket
# caption: some leaves in front of a brown and wood building
# caption: a city from the window of a bus
# caption: the sun shining through some trees
# caption: a wedding couple at sunset at their wedding
# caption: a rotten pear with a knife stuck to it
# caption: a soup bowl on a piece of bread
# caption: a small flower with water droplets
# caption: a red bird sitting on a branch
# caption: a valley with green hills and trees in the background
# caption: a fallen fall maple leaf
# caption: leaves and a bunch of twigs
# caption: 4 different berries
# caption: a little gray bird looking up
# caption: a white tailed deer in the wild flowers near the park
# caption: an island and a small boat in the ocean
# caption: a pumpkin on a table
# caption: a waterfall with water in it
# caption: a beautiful autumn tree leaves
# caption: fall colors in the tree
# caption: a deer that is standing in the woods
# caption: an old burying cemetery in a green field
# caption: a beautiful young woman walking alone in a forest wearing warm clothes
# caption: water running through the middle of a small gorge in iceland
# caption: yellow autumn leaves in the sunlight
# caption: a bus that is parked on the side of the road
# caption: a woman leaning against a wall wearing a gray parka and standing under the hood on her head
# caption: the night on a road in europe
# caption: some trees in the field
# caption: apples on a table
# caption: a lake that has some buildings in it
# caption: pumpkins and gourds on an old wooden shelf
# caption: some water
# caption: a group of people having a bonfire
# caption: a street with yellow leaves
# caption: a person's hand holding a yellow leaf
# caption: the park in autumn
# caption: the stonehences
# caption: the face of an adult golden retrieve in the fall leaves
# caption: pumpkins
# caption: some cookies on a plate
# caption: trees
# caption: a garden watering in the fall
# caption: a person laying in the surf
# caption: some trees in the background with water flowing through them
# caption: someone's face on top of coffee
# caption: neval castle in the fall
# caption: a young woman sitting under a tree
# caption: a fallen red and yellow leaf laying on the grass
# caption: an iceberg in a car
# caption: some grass covered with frost
# caption: an autumn forest with colorful leaves
# caption: people walking in the street near a shopping area
# caption: leaves and the trail
# caption: the front of a house in a street
# caption: some very nice yellow flowers
# caption: trees in the middle of a body of water
# caption: the city from a river
# caption: a small hut in the forest
# caption: the farm at a distance between two orchards and one orchard
# caption: the building from near a pond
# caption: someone standing in leaves at the bottom of the footpath
# caption: a bird perched in a tree
# caption: colorful fallen leaves
# caption: three candles burning on wooden table
# caption: a young girl feeding a horse's nose
# caption: pumpkins with a baby doll sitting next to them
# caption: a man smoking
# caption: flowers on a post near water and buildings
# caption: autumn trees in the mountains
# caption: a couple sitting on top of the smoky mountains during an outdoor fall engagement
# caption: orange pumpkins
# caption: trees covered with fall leaves
# caption: the fruit inside of the leaf
# caption: a woman walking on a path
# caption: yellow and white flowers
# caption: leaves and stairs, and trees in the background
# caption: an empty road covered in colorful leaves
# caption: a forest that looks like a forest
# caption: a small waterfall
# caption: someone holding up an autumn maple leaf
# caption: a tree with yellow leaves in the fall
# caption: sunflowers and sunset in the background
# caption: trees in the fore in front of the mountain covered with snow
# caption: shattered glass
# caption: autumn leaves, background
# caption: an empty trail that has been cleared for generations
# caption: trees in a forest, with sunlight shining through the trees
# caption: some moss on a piece of wood
# caption: trees on hillside
# caption: someone holding a pine cone with their right hand
# caption: a lantern in the middle of autumn leaves
# caption: leaves floating on the water
# caption: a small frog that has just begun in the water
# caption: a bridge and sky
# caption: an autumn day with some leaves
# caption: sunflowers in a field
# caption: a squirrel in the fall leaves
# caption: the plant at the headquarters of the company in north virginia
# caption: some of my gour and squash from my garden
# caption: the cover art for dj d's epy
# caption: corn that looks like corn
# caption: the buds on my house's branches
# caption: the mountains and trees with red leaves
# caption: cinderella's castle through trees
# caption: some candles and christmas decorations
# caption: some orange flowers in a vase
# caption: mountains that are very rocky
# caption: some fake humans are inside the bowl
# caption: some buildings in autumn
# caption: a couple picking apples at mt tima orchards
# caption: a path in the park
# caption: a baby rada
# caption: water, plants, and a rocky shore
# caption: a woman standing outside
# caption: a bunch of trees and leaves with red berries
# caption: leaves hanging from the ceiling
# caption: a smiling, brunette woman in the fall sun by angela + toby photography
# caption: an anonymous mask lying in the grass
# caption: the same trees seen on camera
# caption: an attractive young woman posing
# caption: a black cat sitting in the grass
# caption: a scenic mountain with fall colors
# caption: railroad tracks
# caption: a dog outside
# caption: a loaf with ingredients from the recipe, on a wire rack, in two small bowls on a black table
# caption: the fall colors of leaves
# caption: yellow and green trees in the mountains
# caption: leaves and tree in the fall
# caption: an overhead view of a road, with leaves and trees
# caption: an autumn branch with leaves
# caption: the legs and the soles of a pair of walking shoes on a pile of leaves
# caption: the sun rising over a foggy forest
# caption: a dirt surface with red leaves and brown mulchs
# caption: a waterfall in the middle of trees
# caption: a bunch of red flowers
# caption: woman in the street in an urban style suit
# caption: a tree that has just leaves
# caption: many pumpkins in rows
# caption: the fall foliage
# caption: an island and some rocks
# caption: a girl wearing a coat with the jacket on, she is walking through an archway door
# caption: water with some rocks and a road
# caption: a green fern in the dark
# caption: yo - yo yo in the early sun
# caption: the leaf floating in the blue water
# caption: a hand holding a single brown leaf
# caption: autumn leaves
# caption: a bunch of grapes in a crate outdoors
# caption: the disneyland castle at disneyland
# caption: an empty road with trees in the background
# caption: a walkway surrounded by fall leaves
# caption: the skull wallpaper in a black background
# caption: an outdoor parking area with bright lighting at night
# caption: an interesting looking table
# caption: fall leaves in the autumn
# caption: a red maple tree taken in fall
# caption: three fall leaves on a fence
# caption: a book and scarf with an autumn plaid scarf on top
# caption: pumpkin with heart on it in a cup
# caption: vineyard with vines and bird in it
# caption: a single leaf rests on a tree trunk
# caption: some mountains and clouds in the sky
# caption: an orange apple on the ground
# caption: a lake and trees in the fog
# caption: a night sky with many stars above the trees
# caption: yellow and red flowers in the ground
# caption: the green mushroom in the woods
# caption: a spider on the web
# caption: trees in the foggy area
# caption: a road going up the mountain
# caption: a road in the middle east yukon mountains, canada
# caption: pumpkins in a field
# caption: someone taking photos of someone using their iphones
# caption: leaves in a street
# caption: a mother holding her baby while they are posing for their family portraits by reno baby photographer and video oki smith
# caption: a rocky beach with dark clouds in the distance
# caption: a maple leaf with color
# caption: a tree with autumn leaves and berries
# caption: a woman in the snow
# caption: a bush with berries
# caption: a field with two trees and red apples
# caption: the mountains in autumn with the winding white road below it
# caption: a village with snowy mountains in the background
# caption: some leaves in the sun
# caption: a woman with a hat and scarf
# caption: a tower with blue sky in the background
# caption: some leaves laying on the ground
# caption: a phone on a wooden surface with autumn leaves
# caption: a man in the street with his laptop
# caption: a man taking a picture
# caption: a woman on the edge of a mountain overlooking a river
# caption: flowers in a flower pot on the back of a bench
# caption: leaves covering the ground in a park
# caption: mountains with some trees and a sky
# caption: some type of knit items
# caption: a young woman standing in a tree
# caption: some orange and green trees
# caption: a group of orange pumpkins
# caption: a tower on a hill
# caption: a young woman taking a rest by some trees in the woods during a fall outdoor portrait session
# caption: a man with curly hair sitting on a rock and looking off to the side
# caption: an empty road through trees
# caption: a halloween pumpkin in a pile of leaves
# caption: fog
# caption: some fruit and one apple
# caption: the courtyard of the church in cordoba
# caption: fall leaves hanging on a clothes line
# caption: some red, yellow and green leaves
# caption: pumpkins in the field
# caption: a misty road
# caption: fall leaves
# caption: a body of water
# caption: two kids sitting on a dock in the middle pond
# caption: a tree with the sun setting on it
# caption: some trees in the woods
# caption: some water in the forest
# caption: a road on the mountains
# caption: fall colors in the trees
# caption: houses on a hill side
# caption: pumpkins surrounded by autumn flowers
# caption: rain on a window that is raining
# caption: fall leaves on the branch
# caption: feet wearing shoes
# caption: birds in the trees
# caption: the ground with some fallen leaves
# caption: orange pumpkins with black background
# caption: two girls sitting on the ground
# caption: yellow and orange autumn leaves on the ground
# caption: an old stone church on a hill
# caption: a wreath on the front of a door
# caption: someone with their dog that appears to us on the side
# caption: the text fall baby on the surface of a white table
# caption: an outside area with several trees
# caption: boats in front of the lake
# caption: a field in the foggy
# caption: some autumn leaves growing on a tree
# caption: the view from the top of mount bald
# caption: leaves in the air
# caption: a mountain lake with a hill in the background
# caption: some leaves with different shades
# caption: two sheep standing together
# caption: old street, cars, buildings and pedestrians
# caption: houses with trees on the hillside
# caption: the smoky mountains with colorful trees and clouds
# caption: a river in the woods
# caption: a young man in black t - shirt and gray sneakers looking into the distance
# caption: a sidewalk surrounded with leaves
# caption: a person holding a leaf in the air
# caption: a red front door with leaves scattered on the lawn
# caption: the fall foliage on a rocky slope
# caption: a building with multiple windows
# caption: a small town from above
# caption: a small disney backpack
# caption: a pie with apples around it and flowers around
# caption: a man in a grey sweater and eyeglass looking up to something over his left eye
# caption: the ocean and shoreline
# caption: someone on a bench over a bridge
# caption: some waterfall on the trail in northern ontario, canada
# caption: trees from above, with the top down
# caption: a pumpkin pie with two slices taken from it on a white plate with a red candle, pumpkins and coffee in the background
# caption: an evil pumpkin on the ground and smoke coming from the front
# caption: a woman sitting under a tree
# caption: a field with a few bushes
# caption: an empty pathway in the woods
# caption: yellow leaf on rocks
# caption: waterfall in thailand
# caption: two trees with colorful leaves in the park
# caption: feet and shoes in a field of autumn leaves
# caption: an orange colored tree branch
# caption: pumpkin lit by candles
# caption: trees on a field at sunset
# caption: an elk
# caption: a cat with its owner
# caption: an orange leaf on a branch
# caption: a street sign surrounded by leaves and other foliage
# caption: trees with fog and clouds
# caption: fall in the mountains
# caption: an outbuilding corn farm
# caption: pink flowers
# caption: trees and leaves in the woods
# caption: some yellow leaves in the fall
# caption: a boat sailing near the victoria falls on the niagara falls hike
# caption: some vegetables in a pile
# caption: leaves covering an empty building
# caption: a woman with her hair blowing in the wind
# caption: autumn leaves in the woods photo
# caption: autumn leaves in the ground
# caption: a tree and the grass
# caption: the leaves of a tree that is turning colour
# caption: someone holding a camera in his hand
# caption: an orange autumn sun shining through trees
# caption: two glasses with fruit on them
# caption: the front of a house
# caption: a man holding a baby while they smile as they hold out the faces of pumpkins
# caption: an old castle in the middle of mountains
# caption: a field with a house in it
# caption: some water that is flowing
# caption: a girl holding a whole pumpkin
# caption: a young woman looking into the camera
# caption: an aerial view of the trees surrounding the white mountains
# caption: a pumpkin sitting on an old chair
# caption: the tops of the trees that have begun yellow
# caption: a guy on his own posing in the woods wearing a hat and plaid shirt
# caption: two hands holding small bowl full of food
# caption: a pumpkin and jack and sally nightmare
# caption: the path in the woods
# caption: apples that are laying on top of each other fruits
# ...
# caption: water in a vase on a table
# caption: skier in red trousers and a blue jacket
# caption: a snowy mountain, at sunset
# caption: icicles hanging from the ceiling
# caption: trees covered with snow
# caption: the mountains in an otherwise foggy
# caption: the sun rising through the clouds behind evergreen trees
# caption: the outside and inside layers of ice from inside
# caption: the road in winter time
# caption: snow storm
# caption: trees covered in snow, winter
# caption: snow on bicycles in the street
# caption: a snow covered road
# caption: a christmas tree on a wooden table
# caption: snow falling over a red christmas light at an intersection
# caption: some buildings in the background
# caption: a branch with some flowers and snow
# caption: trees and mountains in the snow
# caption: flowers on a white background
# caption: the rocky coastline in the winter time
# caption: snowy day in montreal, on a small street
# caption: ics on a branch, with water in the background
# caption: a street in the middle of montreal with snow falling
# caption: trees covered in snow on the side of a road
# caption: some water that is inside of a cave
# caption: some ice on the snow
# caption: a little girl with long hair standing outdoors in the snow looking down at her
# caption: some snow covered trees
# caption: trees in the middle of a snowy field
# caption: a person walking in snow with a traffic light
# caption: snowshoes taken in a photo, with a person sitting at the top of one
# caption: a snowboarder doing a jump
# caption: an old stone church with a big tree in the fore
# caption: snowy weather
# caption: a snow covered field with trees
# caption: snow
# caption: a bird flying through the fog
# caption: some snow in the yard
# caption: snow covered water in a river by michael biard
# caption: an iceberg on the water
# caption: icicles hanging on a window
# caption: trees covered in ice in winter
# caption: someone throwing red and orange coning away into the air
# caption: the abandoned house in the middle of the snowy winter
# caption: a person on a bike
# caption: snow and waves at the sea
# caption: snow on the outside of some gate
# caption: trees in the snow in front of an apartment
# caption: a mountain with snow on top
# caption: a baby arctic fox running in snow
# caption: a person hiking in the snow
# caption: some trees in the snow
# caption: icicles on a gut gut roof
# caption: winter forest
# caption: some trees and snow
# caption: snow in the trees and road
# caption: ice and water from the air
# caption: the woods in the snow
# caption: a city street covered in snow
# caption: a forest covered in snow
# caption: snow - covered trees and water
# caption: ice in the winter by julia heffauer for stocks & jones for stocks & jones | on 500px, $ &
# caption: some snow covered mountains
# caption: bryce canyon in utah, where the snow has fallen to the rocks and the trees are covered
# caption: snow that looks like something out in the city
# caption: the lake on the ice trail
# caption: a snowy landscape with footprints leading in
# caption: a snowy landscape on the south side of mount shu, yocona national park, in yosunyoyoo
# caption: the mountains and trees covered in snow
# caption: mountains, glaciers, icebergs and glaciers
# caption: some dry grass on a snow covered field
# caption: two bison bisons in deep snow
# caption: a city in the snow
# caption: a road in the snow
# caption: someone holding up an ice cream dessert
# caption: an object in the ground
# caption: the snow covered path that we rode on
# caption: two horses pulling snow on a flat winter landscape
# caption: a river in the snow
# caption: a ski slope with some people on it
# caption: the snow in new york during winter
# caption: a snowy scene
# caption: a white snowman and white bride with blue eyes on a snowy landscape and lights in the background
# caption: a wolf walking through the snow
# caption: the city street in a winter time
# caption: some snow in the woods
# caption: some snow on trees
# caption: a car covered in snow
# caption: a snowyy look at trees
# caption: an empty building in a snowy landscape
# caption: icebergs on the water in a body of water
# caption: a person on the trail through the woods
# caption: some very snow
# caption: a man walking across the street in winter
# caption: a forest in the snow
# caption: snow covered trees in the sky
# caption: snow and trees around a lake
# caption: the moon over a snow - covered landscape
# caption: snow and trees
# caption: two demonic creatures in the middle of a room with lots of debris
# caption: snow covered trees and some trees in the background
# caption: snow covered trees
# caption: snow in the woods
# caption: several snowboarders walking on the slopes
# caption: two people with the back of a car and some trees in the background
# caption: an old tree covered in snow at sunrise
# caption: the mount thor in the far of the north
# caption: some ick in a tree with ice on it
# caption: the snowballs
# caption: man standing near a river during winter in colorado
# caption: the building that is part of the old farm with snow and trees in the fore
# caption: two dogs pulling a sler through a snowy landscape
# caption: a frozen river and snow covered ground with trees in the background
# caption: a young girl standing in the snow holding a kite
# caption: a man walking in the snow
# caption: a young woman jumping in the snow
# caption: a house with a little christmas tree in front
# caption: a deer in the snow
# caption: the aurora and northern lights at night, with buildings, the snow covered ground and mountains
# caption: a winter scene and trees with white snow on them
# caption: a city in the snow
# caption: a young woman outdoors during a winter snowfall in central vermont
# caption: a snowy field in downtown denver
# caption: snowy - covered metro bus station
# caption: a flower wrapped in ribbons
# caption: a snowy street
# caption: a person on snowed steps looking down the alley
# caption: a snowy mountain view
# caption: snow on a black background
# caption: a path through the park that has no leaves
# caption: the snowy covered roof of a house
# caption: a big tree covered with snow
# caption: people walking the snow down a snowy street
# caption: people hiking in the snow
# caption: snowy mountains with trees and snow
# caption: frosted leaves and ice
# caption: snow - covered trees on the side of a road
# caption: a snow covered mountain with clouds
# caption: mountains and houses covered in snow
# caption: snow falling down the side of a mountain
# caption: snow covered trees and a woman walking away
# caption: a winter scene with mountains and snow
# caption: an indoor model of a city with a few buildings
# caption: a snowy day with some frosty trees
# caption: some snow on a tree branch
# caption: some rocks in the snow
# caption: christmas ornaments hanging from a tree
# caption: snow covered poles at sunset
# caption: icicles and ice from an aerial drone flying above on a mountain trail near the cascade falls area of the white mountains
# caption: snow falling
# caption: some birds hanging on a wire
# caption: snow covered mountain with trees
# caption: latte and some branches on a white surface
# caption: a snowy field that i took photo credit / david lee
# caption: snow in the middle of the road
# caption: snowy trees on a mountain in winter
# caption: some snow and the lake
# caption: some birds flying around some ice
# caption: snow covered forest with trees on the left and blue sky in the top left, finland
# caption: a man with a backpack walking along the shore
# caption: snow covered trees along a snowy lane
# caption: herbs and a star with some spices on it
# caption: a man in the snow near some ice chunks
# caption: a red christmas ball sitting on a table
# caption: snow on trees and snow falling in the wind
# caption: a man in a yellow jacket taking pictures with his phone
# caption: some trees in the snow
# caption: the lake and trees covered in snow
# caption: a snow capped mountain with no one or no name
# caption: snow covered street and sidewalks
# caption: a person standing on a snow covered hill looking into the horizon at sunset
# caption: a snowy day in central london, with people walking around the park
# caption: the decorated christmas mug, made from white clay and green thy, with a pink handle and a pair of scissors
# caption: a small house that is covered with snow
# caption: a river running through a forest
# caption: a rustic house in the mountains during a winter storm
# caption: ice
# caption: snow covered ground and some trees
# caption: snow covered trees
# caption: the trees covered in snow on a hill
# caption: a black and white dog in the snow
# caption: people out in the snow
# caption: a heart made from snow
# caption: a tree in front of an apartment building
# caption: snow on an abandoned wooden chair
# caption: snow covered trees
# caption: snow - covered christmas tree at sunset
# caption: the white glacier ice from above
# caption: a girl standing in the snow
# caption: a snowy mountain range
# caption: snow in the mountains and mountains
# caption: ice and ice in the night
# caption: snow - covered trees along the road in the adi range area
# caption: winter street scene with parked cars
# caption: young boy standing in snow
# caption: a christmas garland with red balls and other christmas decorations
# caption: snow falling on trees in a park
# caption: a mug with some red ornaments
# caption: snowy mountains with trees and snow
# caption: trees and buildings covered in snow
# caption: someone reading a book in the snow
# caption: a child walking through the snowy forest
# caption: the mountains and snow from a boat
# caption: a woman in winter gear
# caption: snow falling on a tree
# caption: a clear blue sky
# caption: a river in the woods covered in snow photo
# caption: a snowy landscape, with some rocks on the snow, and a few clouds in the mountains are behind
# caption: the sunset from a car, in the snow
# caption: some pine branches that have snow on them
# caption: snow covering trees at dusk in winter
# caption: the summit mountain trail looking back towards the snow - shed hills
# caption: an iceberg and mountains in the distance
# caption: an area with some trees and snow
# caption: a small church with white and red colors, with a blue sky and some clouds
# caption: snow with trees in the background
# caption: snow falling from the top
# caption: the snow covered trails in colorado
# caption: a car in a snowy road
# caption: trees with snow falling from them
# caption: the town of halls, on the lake annet
# caption: a lantern in the snow covered with snow
# caption: snow falling
# caption: some kind of flowers covered with snow
# caption: snow in the woods
# caption: a snow covered area with large rocks
# caption: snowy day
# caption: several vehicles covered up in snow
# caption: a snowy scene at the winter wonderland in boston by newyo on flickonme
# caption: the city in winter
# caption: the snowy mountain in finland
# caption: a red and white christmas light on a green tree
# caption: trees from above
# caption: a cat on a wooden rail
# caption: a little boy with a backpack in the woods, winter time
# caption: a woman with snow all around her
# caption: the night in the mountains
# caption: two guys fighting snowball
# caption: our new car
# caption: a mountain reflected in the water
# caption: snow falling over a street in a city
# caption: snow
# caption: the snow - covered pines on a hill
# caption: the ice
# caption: the arctic ocean
# caption: snow covered trees in the woods
# caption: some very snow covered trees
# caption: some leaves on the ground
# caption: snow in the middle of the city, with snow on trees
# caption: a person carrying a piece of wood into their head
# caption: a snowy landscape
# caption: snow covered benches by the water
# caption: the man with a guitar near an icy waterfall
# caption: trees covered in snow
# caption: snow falling from the sky with trees and houses behind
# caption: a snowy tree, near cor
# caption: a beach with some rocks and water
# caption: a person in the snow at the whitetail park
# caption: snow on a dirt path in the forest
# caption: some clouds in the sky
# caption: an animal looking at snow on a fence
# caption: snow covered summits in the distance
# caption: a snowy landscape
# caption: some wooden cottages near water with snowy mountains
# caption: a snowy path through some trees
# caption: miniature trees
# caption: icy snow covered rail on the slopes of the snow covered mountain in st louis
# caption: snow on pine trees
# caption: a woman walking in the snow
# caption: snow on top of a house
# caption: food sitting on the top of a table
# caption: a dog holding on to a piece of meat in the snow
# caption: the road leading into the distance from a snow covered field
# caption: the mountains from the slopes on the mountain house by the lake
# caption: trees in the snow and mountains
# caption: a bird that is sitting on snow
# caption: snowy forest in the snow
# caption: the sun setting on the horizon in snowy weather
# caption: a plant covered in holly
# caption: some very shiny glass items that are on a table
# caption: a snowy winter trail
# caption: snow falling from the sky
# caption: snowy pine trees
# caption: the sunrise from the top of an snowy hill
# caption: the lake in winter
# caption: snow in the mountains and lights
# caption: the snow - covered mountains from an airplane
# caption: snow covered trees on the sidewalk
# caption: ic icicles on a black background
# caption: some kind of ice in a field
# caption: a person walking in the snow
# caption: a ski lift at snow in front of an office building in quebec
# caption: snow covered hills and farm
# caption: the sky filled with snow
# caption: a young woman standing in front of her and looking away with cold weather in the background
# caption: a snow covered trail
# caption: a bench in the snow
# caption: the snowy forest
# caption: snow and ice on the lake in the woods
# caption: the sun setting on a cabin on a snow covered mountain
# caption: a woman crossing the street in a snow storm
# caption: a car under a wind turbine at the end of a road
# caption: the river near a mountain
# caption: a snowy forest and hills
# caption: trees in the middle of a snow covered forest
# caption: ice that is melting and looking like it is from the side view
# caption: winter in the finnish wilderness
# caption: the snow on some trees
# caption: some trees and bushes with snow
# caption: the snow on my car that i found after leaving home
# caption: snow falling from the tree
# caption: pine tree branches on a sunny winter day, taken by my son photo - photographer chris garnet
# caption: a snow - storm in washington
# caption: trees in the snow
# caption: some leaves hanging from a tree branch
# caption: a bench in the snow
# caption: two snowmobiles in the snow
# caption: the cityscape in snow
# caption: the snow and the ice in lake city
# caption: the water running through a snow covered area in the woods
# caption: the shore of the river and ocean in winter time
# caption: a snowy trail with an overhead car
# caption: someone sitting in an apartment with lots of windows that overlook the winter landscape
# caption: someone giving you all the gifts that your husband deserves
# caption: car parked on a snowy day
# caption: a snowy area in the woods
# caption: people in the snow
# caption: snow covered forest with fences
# caption: some snow in the snow
# caption: waterfall with frozen water coming out the ground
# caption: snow on a stairway in the woods
# caption: a boy that is holding an umbrella
# caption: the snowy path towards white lake in winter
# caption: trees covered with snow
# caption: people riding their ski board on a snow covered trail
# caption: a person walking through snow on the street
# caption: a girl running in the snow
# caption: leaves that look like autumn
# caption: a snowy mountain with trees in the middle
# caption: some trees in the snow
# caption: a person sitting on the edge of a snow covered walkway
# caption: the road with snow on it
# caption: a person in the snow
# caption: snow covered trees and water
# caption: a building covered in snow
# caption: a snow covered park in the middle of winter
# caption: the scene from a street in the snow
# caption: some white snow covered trees
# caption: a person looking out at the snow - covered forest
# caption: snow covered trees and road

# %%
# !pip install numba

# from numba import cuda
# device = cuda.get_current_device()
# device.reset()

# # Restart the runtime session to use cuda again
# Out:
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (0.56.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba) (0.39.1)
# Requirement already satisfied: numpy<1.24,>=1.18 in /usr/local/lib/python3.10/dist-packages (from numba) (1.23.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba) (67.7.2)
