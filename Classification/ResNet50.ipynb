# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/4995/project_data.zip" "/content/project_data.zip"

# %%
# !mkdir -p "/content/data"

# %%
# !unzip -q "/content/project_data.zip" -d "/content/data"

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, models
from torch.utils.data import DataLoader, random_split, Subset
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %%
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
# Load the dataset
dataset = datasets.ImageFolder('/content/data/project_data', transform=transform)

# Assuming each class has 6000 images and they are evenly distributed
images_per_class = 6000
train_size_per_class = 4000
val_size_per_class = 1000
test_size_per_class = 1000

# Indices for splitting
train_indices = []
val_indices = []
test_indices = []

for i in range(len(dataset.classes)):
    start_idx = i * images_per_class
    indices = np.arange(start_idx, start_idx + images_per_class)
    np.random.shuffle(indices)

    train_indices.extend(indices[:train_size_per_class])
    val_indices.extend(indices[train_size_per_class:train_size_per_class + val_size_per_class])
    test_indices.extend(indices[train_size_per_class + val_size_per_class:])

# Creating subsets for train, val, and test
train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)
test_dataset = Subset(dataset, test_indices)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
print(len(train_dataset), len(val_dataset), len(test_dataset))
# Out:
# 16000 4000 4000

# %%
model = models.resnet50(pretrained=True)

# Replace the last fully connected layer
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 4)  # 4 classes for seasons

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
best_val_accuracy = 0.0
best_model_path = 'best_model_resnet50.pth'
patience = 5
patience_counter = 0
num_epochs = 10

# %%
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader)}")

    # Validation phase
    model.eval()
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_accuracy = val_correct / val_total
    print(f'Epoch {epoch+1}/{num_epochs}, Validation Accuracy: {val_accuracy*100}%')

    # Check if model improved
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        torch.save(model.state_dict(), best_model_path)
        print(f'Model saved as validation accuracy improved to {val_accuracy*100}%')
        patience_counter = 0  # reset counter if model improved
    else:
        patience_counter += 1
        print(f'No improvement in validation accuracy for {patience_counter} epochs.')

    # Early stopping check
    if patience_counter >= patience:
        print(f'Stopping training early as there has been no improvement for {patience} epochs.')
        break
print('Finished Training')
# Out:
# Epoch 1/10, Loss: 0.9728604649305344
# Epoch 1/10, Validation Accuracy: 64.35%
# Model saved as validation accuracy improved to 64.35%
# Epoch 2/10, Loss: 0.888639491379261
# Epoch 2/10, Validation Accuracy: 68.15%
# Model saved as validation accuracy improved to 68.15%
# Epoch 3/10, Loss: 0.8425239207148552
# Epoch 3/10, Validation Accuracy: 67.4%
# No improvement in validation accuracy for 1 epochs.
# Epoch 4/10, Loss: 0.8220744952559471
# Epoch 4/10, Validation Accuracy: 66.10000000000001%
# No improvement in validation accuracy for 2 epochs.
# Epoch 5/10, Loss: 0.7954442764520645
# Epoch 5/10, Validation Accuracy: 69.27499999999999%
# Model saved as validation accuracy improved to 69.27499999999999%
# Epoch 6/10, Loss: 0.7697484391331673
# Epoch 6/10, Validation Accuracy: 68.22500000000001%
# No improvement in validation accuracy for 1 epochs.
# Epoch 7/10, Loss: 0.7567076657414437
# Epoch 7/10, Validation Accuracy: 68.075%
# No improvement in validation accuracy for 2 epochs.
# Epoch 8/10, Loss: 0.7612043339014053
# Epoch 8/10, Validation Accuracy: 66.07499999999999%
# No improvement in validation accuracy for 3 epochs.
# Epoch 9/10, Loss: 0.7717637265324593
# Epoch 9/10, Validation Accuracy: 69.72500000000001%
# Model saved as validation accuracy improved to 69.72500000000001%
# Epoch 10/10, Loss: 0.7024496003985405
# Epoch 10/10, Validation Accuracy: 68.45%
# No improvement in validation accuracy for 1 epochs.
# Finished Training

# %%
model.load_state_dict(torch.load(best_model_path))
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy on the test images: {100 * correct / total}%')
# Out:
# Accuracy on the test images: 68.8%
